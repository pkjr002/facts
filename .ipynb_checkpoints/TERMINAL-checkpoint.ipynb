# %%
# !ls
# Out:
# ACKNOWLEDGEMENTS.md
# CITATION.cff
# docs
# experiments
# experiments-pkjr002
# FACTS.py
# input_files
# JupNbk
# LICENSE
# modules
# modules copy
# modules-data
# notebooks
# NZrerun.OG.termOP-MOD.txt
# NZrerun.OG.termOP.txt
# NZrerun.OG.txt
# onemodule.termOP.txt
# __pycache__
# Q-err.txt
# README.md
# requirements.txt
# re.session.amarel1.amarel.rutgers.edu.pk695.019394.0009
# re.session.amarel1.amarel.rutgers.edu.pk695.019394.0011
# re.session.amarel1.amarel.rutgers.edu.pk695.019394.0012
# re.session.amarel1.amarel.rutgers.edu.pk695.019394.0013
# re.session.amarel1.amarel.rutgers.edu.pk695.019394.0014
# re.session.amarel2.amarel.rutgers.edu.pk695.019394.0015
# re.session.amarel2.amarel.rutgers.edu.pk695.019394.0017
# re.session.amarel2.amarel.rutgers.edu.pk695.019394.0018
# re.session.hal0157.amarel.rutgers.edu.pk695.019394.0019
# re.session.hal0157.amarel.rutgers.edu.pk695.019394.0020
# resources
# runFACTS.py
# run.sh
# scripts
# Untitled.ipynb

# %%
# All NZ TG with the NYC TG to check for ESL dependency.
# !./run.sh
# Out:
# EnTK session: re.session.hal0157.amarel.rutgers.edu.pk695.019394.0019
# Creating AppManager
# Setting up ZMQ queues                                                         ok
# AppManager initialized                                                        ok
# Validating and assigning resource manager                                     ok
# Setting up ZMQ queues                                                        n/a
# new session: [re.session.hal0157.amarel.rutgers.edu.pk695.019394.0019]         \
# database   : [mongodb://facts:****@95.217.193.116:27017/facts]                ok
# create pilot manager                                                          ok
# submit 1 pilot(s)
#         pilot.0000   rutgers.amarel           16 cores       0 gpus           ok
# All components created
# Update: NZrerun.OG.NZ.TG.NYC.temperature.fair.temperature state: SCHEDULING
# Update: NZrerun.OG.NZ.TG.NYC.temperature.fair.temperature.preprocess state: SCHEDULING
# ...

# %%
# All NZ TG ONLY: to check for ESL dependency.
# !./run.sh
# Out:
# EnTK session: re.session.hal0155.amarel.rutgers.edu.pk695.019394.0021
# Creating AppManager
# Setting up ZMQ queues                                                         ok
# AppManager initialized                                                        ok
# Validating and assigning resource manager                                     ok
# Setting up ZMQ queues                                                        n/a
# new session: [re.session.hal0155.amarel.rutgers.edu.pk695.019394.0021]         \
# database   : [mongodb://facts:****@95.217.193.116:27017/facts]                ok
# create pilot manager                                                          ok
# submit 1 pilot(s)
#         pilot.0000   rutgers.amarel           16 cores       0 gpus           ok
# Update: NZrerun.OG.NZ.TG.temperature.fair.temperature state: SCHEDULING
# All components created
# Update: NZrerun.OG.NZ.TG.temperature.fair.temperature.preprocess state: SCHEDULING
# ...

# %%
# (NO ESL) Cleaned up the exp folder. Now run just the TG locations of NZ.
# !./run.sh
# Out:
# EnTK session: re.session.hal0155.amarel.rutgers.edu.pk695.019395.0000
# Creating AppManager
# Setting up ZMQ queues                                                         ok
# AppManager initialized                                                        ok
# Validating and assigning resource manager                                     ok
# Setting up ZMQ queues                                                        n/a
# new session: [re.session.hal0155.amarel.rutgers.edu.pk695.019395.0000]         \
# database   : [mongodb://facts:****@95.217.193.116:27017/facts]                ok
# create pilot manager                                                          ok
# submit 1 pilot(s)
#         pilot.0000   rutgers.amarel           16 cores       0 gpus           ok
# All components created
# Update: NZrerun.OG.temperature.fair.temperature state: SCHEDULING
# Update: NZrerun.OG.temperature.fair.temperature.preprocess state: SCHEDULING
# ...

# %%
# (NO ESL) NZ 2km location.lst run
# !./run.sh
