# %% [markdown]
# ## $\color{Green}{\text{GMD Table 3: GMSL from Modules}}$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import netCDF4 as nc
from pandas.plotting import table 
import xarray as xr

# %% [markdown]
# #### $\color{blue}{\text{Module data from Bob's run on Amarel}}$

# %%
# Load FACTS workflow data as a dataframe.
df = pd.read_fwf('../../001_IP_names_Modules_Data/Table_3_GMSL-Proj_2100_V1_OP_TEST.txt')
df
# Out:
#    Component       Module         sub_Module  \
# 0       GSAT         fair        temperature
# 1         TE          tlm      oceandynamics
# 2         TE      ipccar5   thermalexpansion
# 3   Glaciers       kopp14           glaciers
# 4   Glaciers      ipccar5           glaciers
# 5   Glaciers      ipccar5      glacierscmip6
# 6   Glaciers      ipccar5       glaciersfair
# 7   Glaciers      ipccar6    gmipemuglaciers
# 8   Glaciers   emulandice           glaciers
# 9       GrIS      ipccar5          icesheets
# 10      GrIS     bamber19          icesheets
# 11      GrIS      ipccar6  ismipemuicesheets
# 12      GrIS       kopp14          icesheets
# 13      GrIS  FittedISMIP               GrIS
# 14      GrIS   emulandice               GrIS
# 15       AIS      ipccar5          icesheets
# 16       AIS     bamber19          icesheets
# 17       AIS      ipccar6  ismipemuicesheets
# 18       AIS       kopp14          icesheets
# 19       AIS    deconto16                AIS
# 20       AIS    deconto21                AIS
# 21       AIS   emulandice                AIS
# 22       AIS      ipccar6          larmipAIS
# 23       AIS       larmip                AIS
# 24       LWS       kopp14   landwaterstorage
# 25       LWS          ssp   landwaterstorage
#
#                                       Data_File
# 0          temperature.fair.temperature_gsat.nc
# 1           ocean.tlm.oceandynamics_globalsl.nc
# 2                                           XXX
# 3                                           XXX
# 4      ar5glaciers.ipccar5.glaciers_globalsl.nc
# 5                                           XXX
# 6                                           XXX
# 7                                           XXX
# 8   emuglaciers.emulandice.glaciers_globalsl.nc
# 9                                           XXX
# 10                                          XXX
# 11                                          XXX
# 12                                          XXX
# 13      GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc
# 14          emuGrIS.emulandice.GrIS_globalsl.nc
# 15     ar5AIS.ipccar5.icesheets_AIS_globalsl.nc
# 16                                          XXX
# 17                                          XXX
# 18                                          XXX
# 19                                          XXX
# 20                                          XXX
# 21            emuAIS.emulandice.AIS_globalsl.nc
# 22                                          XXX
# 23                larmip.larmip.AIS_globalsl.nc
# 24                                          XXX
# 25         lws.ssp.landwaterstorage_globalsl.nc

# %% [markdown]
# #### $\color{Red}{\text{Use Workflow data from ==> facts-experiments/221206}}$

# %%
MODNO       = df.index.values;   # Number of datasets Module outputs
SCENARIO    = ['ssp126', 'ssp245', 'ssp585'];
YEAR        = 2100; # Percentile Year for the table.    
#
# Temp DF to store all .nc O/P.      
df_TEMP      = []
#        
for scenario in SCENARIO:
    # Define pd DF columns to append.
    PERCENTILE  = '%ile({arg2})'.format(arg2=scenario)
    percentile = np.nan
    df[PERCENTILE] = percentile
    df[PERCENTILE] = df[PERCENTILE].astype('object') 
    #
    for val in MODNO: 
        #
        MODULE = df["Module"][val];  SUB_MODULE = df["sub_Module"][val]; COMP = df["Component"][val];
        # Skip if data is absent.
        if df["Data_File"][val] == 'XXX':
           continue 
        #
        # Pick the data files & Import nc file to dataframe. 
        # Pick the data files & Import nc file to dataframe. 
        dataFOLDER  = '/projects/kopp/facts-experiments/221206/coupling.{arg1}/output/'.format(arg1=scenario)
        dataFILE    = 'coupling.{arg1}.'.format(arg1=scenario) + df["Data_File"][val]
        d_nc        = xr.open_dataset(dataFOLDER + dataFILE)
        #
        # Percentile calculation.
        percentList = [50, 17, 83]          #[50, 5, 17, 83, 95]
        # Find year index to pick SLC value
        Yind        = np.where(d_nc["years"].values == YEAR)[0][0]
        if SUB_MODULE == 'temperature':
            GMSL    = (d_nc["surface_temperature"][:,Yind,0].values)/1   # Convert to meters.
        else:
            GMSL    = (d_nc["sea_level_change"][:,Yind,0].values)/1      # Convert to meters.
        # Find Percentiles.
        pcntle = np.percentile(GMSL[:], percentList );    pcntle = np.around(pcntle,2)
        #
        df.at[val,PERCENTILE] = [pcntle[0], pcntle[1],pcntle[2]]
        # Print the OP.
print('GMSL Component Projections for ',d_nc["years"][Yind].values)    
#show(df)
df
# Out:
# GMSL Component Projections for  2100
#    Component       Module         sub_Module  \
# 0       GSAT         fair        temperature
# 1         TE          tlm      oceandynamics
# 2         TE      ipccar5   thermalexpansion
# 3   Glaciers       kopp14           glaciers
# 4   Glaciers      ipccar5           glaciers
# 5   Glaciers      ipccar5      glacierscmip6
# 6   Glaciers      ipccar5       glaciersfair
# 7   Glaciers      ipccar6    gmipemuglaciers
# 8   Glaciers   emulandice           glaciers
# 9       GrIS      ipccar5          icesheets
# 10      GrIS     bamber19          icesheets
# 11      GrIS      ipccar6  ismipemuicesheets
# 12      GrIS       kopp14          icesheets
# 13      GrIS  FittedISMIP               GrIS
# 14      GrIS   emulandice               GrIS
# 15       AIS      ipccar5          icesheets
# 16       AIS     bamber19          icesheets
# 17       AIS      ipccar6  ismipemuicesheets
# 18       AIS       kopp14          icesheets
# 19       AIS    deconto16                AIS
# 20       AIS    deconto21                AIS
# 21       AIS   emulandice                AIS
# 22       AIS      ipccar6          larmipAIS
# 23       AIS       larmip                AIS
# 24       LWS       kopp14   landwaterstorage
# 25       LWS          ssp   landwaterstorage
#
#                                       Data_File            %ile(ssp126)  \
# 0          temperature.fair.temperature_gsat.nc      [1.64, 1.38, 1.94]
# 1           ocean.tlm.oceandynamics_globalsl.nc  [142.0, 111.0, 173.17]
# 2                                           XXX                     NaN
# 3                                           XXX                     NaN
# 4      ar5glaciers.ipccar5.glaciers_globalsl.nc     [89.0, 53.0, 132.0]
# 5                                           XXX                     NaN
# 6                                           XXX                     NaN
# 7                                           XXX                     NaN
# 8   emuglaciers.emulandice.glaciers_globalsl.nc   [92.0, 69.83, 109.17]
# 9                                           XXX                     NaN
# 10                                          XXX                     NaN
# 11                                          XXX                     NaN
# 12                                          XXX                     NaN
# 13      GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc     [77.0, 59.83, 96.0]
# 14          emuGrIS.emulandice.GrIS_globalsl.nc     [52.0, 16.0, 101.0]
# 15     ar5AIS.ipccar5.icesheets_AIS_globalsl.nc   [77.5, -9.17, 142.17]
# 16                                          XXX                     NaN
# 17                                          XXX                     NaN
# 18                                          XXX                     NaN
# 19                                          XXX                     NaN
# 20                                          XXX                     NaN
# 21            emuAIS.emulandice.AIS_globalsl.nc   [91.0, 26.83, 142.17]
# 22                                          XXX                     NaN
# 23                larmip.larmip.AIS_globalsl.nc  [124.5, 55.83, 270.34]
# 24                                          XXX                     NaN
# 25         lws.ssp.landwaterstorage_globalsl.nc      [30.0, 16.0, 41.0]
#
#               %ile(ssp245)             %ile(ssp585)
# 0       [2.61, 2.24, 3.02]       [4.74, 4.09, 5.33]
# 1    [191.0, 153.0, 227.0]  [289.0, 242.98, 336.34]
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4   [108.5, 70.49, 158.17]  [150.0, 116.66, 215.17]
# 5                      NaN                      NaN
# 6                      NaN                      NaN
# 7                      NaN                      NaN
# 8    [123.5, 100.0, 142.0]    [176.0, 149.0, 196.0]
# 9                      NaN                      NaN
# 10                     NaN                      NaN
# 11                     NaN                      NaN
# 12                     NaN                      NaN
# 13    [101.5, 81.0, 125.0]  [143.5, 116.83, 174.17]
# 14   [76.0, 39.83, 123.17]    [127.0, 73.83, 162.0]
# 15   [70.5, -19.0, 137.17]    [49.0, -37.85, 106.0]
# 16                     NaN                      NaN
# 17                     NaN                      NaN
# 18                     NaN                      NaN
# 19                     NaN                      NaN
# 20                     NaN                      NaN
# 21    [88.5, 23.0, 139.17]    [84.5, 19.47, 134.85]
# 22                     NaN                      NaN
# 23  [128.0, 55.49, 304.68]   [157.0, 63.83, 310.51]
# 24                     NaN                      NaN
# 25      [31.0, 16.0, 43.0]      [29.0, 17.0, 41.17]

# %% [markdown]
# #### $\color{Red}{\text{Use Workflow data from ==> facts-experiments/coupling.}}$

# %%
MODNO       = df.index.values;   # Number of datasets Module outputs
SCENARIO    = ['ssp126', 'ssp245', 'ssp585'];
YEAR        = 2100; # Percentile Year for the table.    
#
# Temp DF to store all .nc O/P.      
df_TEMP      = []
#        
for scenario in SCENARIO:
    # Define pd DF columns to append.
    PERCENTILE  = '%ile({arg2})'.format(arg2=scenario)
    percentile = np.nan
    df[PERCENTILE] = percentile
    df[PERCENTILE] = df[PERCENTILE].astype('object') 
    #
    for val in MODNO: 
        #
        MODULE = df["Module"][val];  SUB_MODULE = df["sub_Module"][val]; COMP = df["Component"][val];
        # Skip if data is absent.
        if df["Data_File"][val] == 'XXX':
           continue 
        #
        # Pick the data files & Import nc file to dataframe. 
        if scenario == 'ssp585':
            dataFOLDER = '/projects/kopp/facts-experiments/coupling.{arg1}.localhost/output/'.format(arg1=scenario)
            dataFILE   = 'coupling.{arg1}.localhost.'.format(arg1=scenario) + df.loc[val].at['Data_File']
        else:
            dataFOLDER = '/projects/kopp/facts-experiments/coupling.{arg1}/output/'.format(arg1=scenario)
            dataFILE   = 'coupling.{arg1}.'.format(arg1=scenario) + df.loc[val].at['Data_File']
        d_nc        = xr.open_dataset(dataFOLDER + dataFILE)
        #
        # Percentile calculation.
        percentList = [50, 17, 83]          #[50, 5, 17, 83, 95]
        # Find year index to pick SLC value
        Yind        = np.where(d_nc["years"].values == YEAR)[0][0]
        if SUB_MODULE == 'temperature':
            GMSL    = (d_nc["surface_temperature"][:,Yind,0].values)/1   # Convert to meters.
        else:
            GMSL    = (d_nc["sea_level_change"][:,Yind,0].values)/1      # Convert to meters.
        # Find Percentiles.
        pcntle = np.percentile(GMSL[:], percentList );    pcntle = np.around(pcntle,2)
        #
        df.at[val,PERCENTILE] = [pcntle[0], pcntle[1],pcntle[2]]
        # Print the OP.
print('GMSL Component Projections for ',d_nc["years"][Yind].values)    
#show(df)
df
# Out:
# GMSL Component Projections for  2100
#    Component       Module         sub_Module  \
# 0       GSAT         fair        temperature
# 1         TE          tlm      oceandynamics
# 2         TE      ipccar5   thermalexpansion
# 3   Glaciers       kopp14           glaciers
# 4   Glaciers      ipccar5           glaciers
# 5   Glaciers      ipccar5      glacierscmip6
# 6   Glaciers      ipccar5       glaciersfair
# 7   Glaciers      ipccar6    gmipemuglaciers
# 8   Glaciers   emulandice           glaciers
# 9       GrIS      ipccar5          icesheets
# 10      GrIS     bamber19          icesheets
# 11      GrIS      ipccar6  ismipemuicesheets
# 12      GrIS       kopp14          icesheets
# 13      GrIS  FittedISMIP               GrIS
# 14      GrIS   emulandice               GrIS
# 15       AIS      ipccar5          icesheets
# 16       AIS     bamber19          icesheets
# 17       AIS      ipccar6  ismipemuicesheets
# 18       AIS       kopp14          icesheets
# 19       AIS    deconto16                AIS
# 20       AIS    deconto21                AIS
# 21       AIS   emulandice                AIS
# 22       AIS      ipccar6          larmipAIS
# 23       AIS       larmip                AIS
# 24       LWS       kopp14   landwaterstorage
# 25       LWS          ssp   landwaterstorage
#
#                                       Data_File           %ile(ssp126)  \
# 0          temperature.fair.temperature_gsat.nc     [1.64, 1.35, 2.01]
# 1           ocean.tlm.oceandynamics_globalsl.nc  [140.0, 114.0, 173.0]
# 2                                           XXX                    NaN
# 3                                           XXX                    NaN
# 4      ar5glaciers.ipccar5.glaciers_globalsl.nc   [90.0, 63.83, 123.0]
# 5                                           XXX                    NaN
# 6                                           XXX                    NaN
# 7                                           XXX                    NaN
# 8   emuglaciers.emulandice.glaciers_globalsl.nc   [90.0, 68.83, 110.0]
# 9                                           XXX                    NaN
# 10                                          XXX                    NaN
# 11                                          XXX                    NaN
# 12                                          XXX                    NaN
# 13      GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc    [77.0, 61.0, 97.17]
# 14          emuGrIS.emulandice.GrIS_globalsl.nc    [56.0, 16.0, 104.0]
# 15     ar5AIS.ipccar5.icesheets_AIS_globalsl.nc    [65.5, -8.0, 140.0]
# 16                                          XXX                    NaN
# 17                                          XXX                    NaN
# 18                                          XXX                    NaN
# 19                                          XXX                    NaN
# 20                                          XXX                    NaN
# 21            emuAIS.emulandice.AIS_globalsl.nc  [85.0, 32.83, 146.17]
# 22                                          XXX                    NaN
# 23                larmip.larmip.AIS_globalsl.nc   [130.0, 56.0, 259.0]
# 24                                          XXX                    NaN
# 25         lws.ssp.landwaterstorage_globalsl.nc    [33.0, 20.83, 45.0]
#
#               %ile(ssp245)            %ile(ssp585)
# 0        [2.61, 2.2, 3.14]      [4.68, 3.98, 5.55]
# 1   [190.0, 157.0, 231.17]  [293.0, 242.0, 352.17]
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4     [109.0, 79.0, 147.0]   [159.0, 116.0, 212.0]
# 5                      NaN                     NaN
# 6                      NaN                     NaN
# 7                      NaN                     NaN
# 8     [122.0, 98.0, 143.0]   [177.0, 150.0, 202.0]
# 9                      NaN                     NaN
# 10                     NaN                     NaN
# 11                     NaN                     NaN
# 12                     NaN                     NaN
# 13    [101.0, 83.0, 124.0]   [139.0, 115.0, 177.0]
# 14     [80.0, 40.0, 126.0]    [126.0, 86.0, 177.0]
# 15   [59.5, -15.0, 134.17]    [40.0, -37.0, 117.0]
# 16                     NaN                     NaN
# 17                     NaN                     NaN
# 18                     NaN                     NaN
# 19                     NaN                     NaN
# 20                     NaN                     NaN
# 21   [82.0, 29.83, 144.17]    [83.0, 31.66, 144.0]
# 22                     NaN                     NaN
# 23   [137.0, 56.83, 283.0]  [148.5, 59.83, 338.34]
# 24                     NaN                     NaN
# 25     [33.0, 20.83, 45.0]     [33.0, 20.83, 45.0]
