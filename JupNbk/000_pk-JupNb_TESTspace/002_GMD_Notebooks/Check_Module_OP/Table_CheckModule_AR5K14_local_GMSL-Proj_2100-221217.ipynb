# %% [markdown]
# ## <font color=blue>Check Individual Module *AR5K14* <font color=green> **local** </font>  Results</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import netCDF4 as nc
from pandas.plotting import table 
import xarray as xr

# %% [markdown]
# #### <font color=blue>List of *Modules* and <font color=green> **Datasets** </font> to be used </font>

# %%
# Load FACTS workflow data as a dataframe.
#df = pd.read_fwf('../001_GMD_IP_Modules_Data/ModuleTest_DataFile_List_ar5k14.local.txt',comment = '#')
df = pd.read_fwf('../001_GMD_IP_Modules_Data/ModuleTest_DataFile_List_ar5k14.local-221217.txt',comment = '#')
df
# Out:
#    Component     Module          sub_Module  \
# 0         TE     kopp14       sterodynamics
# 1         TE    ipccar5    thermalexpansion
# 2   Glaciers     kopp14            glaciers
# 3   Glaciers    ipccar5            glaciers
# 4       GrIS    ipccar5           icesheets
# 5       GrIS     kopp14           icesheets
# 6        AIS  deconto16                 AIS
# 7       EAIS    ipccar5           icesheets
# 8       EAIS  deconto16                 AIS
# 9       EAIS     kopp14           icesheets
# 10      WAIS    ipccar5           icesheets
# 11      WAIS  deconto16                 AIS
# 12      WAIS     kopp14           icesheets
# 13       LWS     kopp14    landwaterstorage
# 14       VLM     kopp14  verticallandmotion
#
#                                             DataFile
# 0   k14sterodynamics.kopp14.sterodynamics_localsl.nc
# 1          ar5TE.ipccar5.thermalexpansion_localsl.nc
# 2             k14glaciers.kopp14.glaciers_localsl.nc
# 3            ar5glaciers.ipccar5.glaciers_localsl.nc
# 4      ar5icesheets.ipccar5.icesheets_GIS_localsl.nc
# 5       k14icesheets.kopp14.icesheets_GIS_localsl.nc
# 6             deconto16.deconto16.AIS_AIS_localsl.nc
# 7     ar5icesheets.ipccar5.icesheets_EAIS_localsl.nc
# 8            deconto16.deconto16.AIS_EAIS_localsl.nc
# 9      k14icesheets.kopp14.icesheets_EAIS_localsl.nc
# 10    ar5icesheets.ipccar5.icesheets_WAIS_localsl.nc
# 11           deconto16.deconto16.AIS_WAIS_localsl.nc
# 12     k14icesheets.kopp14.icesheets_WAIS_localsl.nc
# 13         k14lws.kopp14.landwaterstorage_localsl.nc
# 14       k14vlm.kopp14.verticallandmotion_localsl.nc

# %% [markdown]
# #### <font color=blue> **OPTIONAL USE**: <font color=green> *Write nc data details to a file* </font>

# %%
EXPDATE     = 221217
MODNO       = df.index.values;   # Number of datasets Module outputs
SCENARIO    = ['rcp26', 'rcp45', 'rcp85']; 
#        
file = open("ModuleData_Info_AR5K14.local-{arg1}.txt".format(arg1=EXPDATE), "w")
#
for val in MODNO: 
    for scenario in SCENARIO:
        #
        MODULE = df["Module"][val];  SUB_MODULE = df["sub_Module"][val]; COMP = df["Component"][val];
        # Skip if data is absent.
        if df["DataFile"][val] == 'XXX':
           continue 
        #
        # Pick the data files & Import nc file to dataframe. 
        dataFOLDER  = '/projects/kopp/facts-experiments/{arg2}/ar5k14.{arg1}/output/'.format(arg1=scenario,arg2=EXPDATE)
        dataFILE    = 'ar5k14.{arg1}.'.format(arg1=scenario) + df["DataFile"][val]
        d_nc        = xr.open_dataset(dataFOLDER + dataFILE)
        d_nc
    file.write( "DataFILE ==> "+str(df["DataFile"][val])+"\n"+ str(d_nc.dims) + "\n" + str(d_nc.data_vars)+ "\n" + str(d_nc.coords)+"\n"+"-------------"+"\n"+"\n" )
        #
file.close()

# %% [markdown]
# #### $\color{Red}{\text{Load Module data from ==> facts-experiments}}$

# %%
EXPDATE     = 221217
MODNO       = df.index.values;   # Number of datasets Module outputs
SCENARIO    = ['rcp26', 'rcp45', 'rcp85']; 
YEAR        = 2100; # Percentile Year for the table.                
#
# Temp DF to store all .nc O/P.      
df_TEMP      = []
#        
for scenario in SCENARIO:
    # Define pd DF columns to append.
    PERCENTILE  = '%ile({arg2})'.format(arg2=scenario)
    percentile = np.nan
    df[PERCENTILE] = percentile
    df[PERCENTILE] = df[PERCENTILE].astype('object') 
    #
    for val in MODNO: 
        #
        MODULE = df["Module"][val];  SUB_MODULE = df["sub_Module"][val]; COMP = df["Component"][val]; DATAFILE = df["DataFile"][val];
        # Skip if data is absent.
        if df["DataFile"][val] == 'XXX':
           continue 
        #
        # Pick the data files & Import nc file to dataframe. 
        dataFOLDER  = '/projects/kopp/facts-experiments/{arg2}/ar5k14.{arg1}/output/'.format(arg1=scenario,arg2=EXPDATE)
        dataFILE    = 'ar5k14.{arg1}.'.format(arg1=scenario) + df["DataFile"][val]
        d_nc        = xr.open_dataset(dataFOLDER + dataFILE)
        d_nc
        #
        # Percentile calculation.
        percentList = [50, 17, 83]          #[50, 5, 17, 83, 95]
        # Find year index to pick SLC value
        Yind    = np.where(d_nc["years"].values == YEAR)[0][0]
        GMSL    = (d_nc["sea_level_change"][:,Yind,0].values)/1       
        # Find Percentiles.
        pcntle = np.percentile(GMSL[:], percentList );    pcntle = np.around(pcntle,2)
        #
        # df.at[val,PERCENTILE] = [pcntle[0], pcntle[1],pcntle[2]]
        df.at[val,PERCENTILE] = f'{pcntle[0]:2.2f} ({pcntle[1]:2.2f} , {pcntle[2]:2.2f})' 
        # Print the OP.
print('GMSL Component Projections for ',d_nc["years"][Yind].values)    
#show(df)
df
# Out:
# GMSL Component Projections for  2100
#    Component     Module          sub_Module  \
# 0         TE     kopp14       sterodynamics
# 1         TE    ipccar5    thermalexpansion
# 2   Glaciers     kopp14            glaciers
# 3   Glaciers    ipccar5            glaciers
# 4       GrIS    ipccar5           icesheets
# 5       GrIS     kopp14           icesheets
# 6        AIS  deconto16                 AIS
# 7       EAIS    ipccar5           icesheets
# 8       EAIS  deconto16                 AIS
# 9       EAIS     kopp14           icesheets
# 10      WAIS    ipccar5           icesheets
# 11      WAIS  deconto16                 AIS
# 12      WAIS     kopp14           icesheets
# 13       LWS     kopp14    landwaterstorage
# 14       VLM     kopp14  verticallandmotion
#
#                                             DataFile  \
# 0   k14sterodynamics.kopp14.sterodynamics_localsl.nc
# 1          ar5TE.ipccar5.thermalexpansion_localsl.nc
# 2             k14glaciers.kopp14.glaciers_localsl.nc
# 3            ar5glaciers.ipccar5.glaciers_localsl.nc
# 4      ar5icesheets.ipccar5.icesheets_GIS_localsl.nc
# 5       k14icesheets.kopp14.icesheets_GIS_localsl.nc
# 6             deconto16.deconto16.AIS_AIS_localsl.nc
# 7     ar5icesheets.ipccar5.icesheets_EAIS_localsl.nc
# 8            deconto16.deconto16.AIS_EAIS_localsl.nc
# 9      k14icesheets.kopp14.icesheets_EAIS_localsl.nc
# 10    ar5icesheets.ipccar5.icesheets_WAIS_localsl.nc
# 11           deconto16.deconto16.AIS_WAIS_localsl.nc
# 12     k14icesheets.kopp14.icesheets_WAIS_localsl.nc
# 13         k14lws.kopp14.landwaterstorage_localsl.nc
# 14       k14vlm.kopp14.verticallandmotion_localsl.nc
#
#                   %ile(rcp26)               %ile(rcp45)  \
# 0    196.48 (-27.67 , 420.63)   310.41 (46.26 , 574.56)
# 1          0.16 (0.12 , 0.18)        0.20 (0.18 , 0.23)
# 2      89.55 (67.58 , 110.94)   102.38 (77.19 , 127.07)
# 3      75.00 (49.00 , 104.00)    94.00 (64.00 , 128.00)
# 4       34.00 (24.00 , 45.00)     41.00 (30.00 , 56.00)
# 5       26.12 (15.07 , 48.03)     37.28 (15.19 , 64.69)
# 6    127.75 (-32.45 , 349.13)  399.98 (216.05 , 728.93)
# 7        9.00 (-2.00 , 20.00)      8.00 (-3.00 , 19.00)
# 8     58.69 (-41.03 , 234.23)  221.77 (-38.43 , 511.58)
# 9      -7.16 (-66.14 , 88.09)    -8.43 (-72.41 , 86.51)
# 10    67.00 (-13.00 , 144.00)   57.50 (-23.00 , 136.00)
# 11  -15.87 (-101.91 , 315.50)   156.84 (18.91 , 454.64)
# 12     42.52 (-9.32 , 119.95)   39.15 (-15.67 , 112.66)
# 13      48.00 (30.00 , 67.00)     48.00 (30.00 , 67.00)
# 14   143.00 (135.00 , 152.00)  143.00 (135.00 , 152.00)
#
#                   %ile(rcp85)
# 0    477.19 (127.81 , 826.56)
# 1          0.32 (0.28 , 0.36)
# 2    134.39 (106.23 , 161.24)
# 3     129.00 (90.00 , 176.00)
# 4       71.00 (50.00 , 98.00)
# 5      59.61 (31.98 , 108.91)
# 6   832.66 (462.76 , 1460.44)
# 7        6.00 (-6.00 , 17.00)
# 8     401.47 (-6.23 , 791.52)
# 9     -17.10 (-84.95 , 83.41)
# 10    40.00 (-41.00 , 121.17)
# 11   540.69 (341.74 , 776.85)
# 12    26.79 (-31.29 , 104.53)
# 13      48.00 (30.00 , 67.00)
# 14   143.00 (135.00 , 152.00)

# %%
df.to_excel(r'Table_CheckModule_AR5K14_local_GMSL-Proj_2100-{arg1}.xlsx'.format(arg1=EXPDATE), index=False)
