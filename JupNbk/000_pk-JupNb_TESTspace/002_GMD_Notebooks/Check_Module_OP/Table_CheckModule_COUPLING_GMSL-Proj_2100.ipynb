# %% [markdown]
# ## $\color{Green}{\text{Check Individual Module (COUPLING) Results}}$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import netCDF4 as nc
from pandas.plotting import table 
import xarray as xr

# %% [markdown]
# #### $\color{blue}{\text{List of Modules and Data to be used}}$

# %%
# Load FACTS workflow data as a dataframe.
df = pd.read_fwf('../001_GMD_IP_Modules_Data/ModuleTest_DataFile_List_coupling.txt',comment = '#')
df
# Out:
#    Component       Module        sub_Module  \
# 0       GSAT         fair       temperature
# 1       GSAT         fair       temperature
# 2       GSAT         fair       temperature
# 3         TE          tlm     sterodynamics
# 4   Glaciers      ipccar5          glaciers
# 5   Glaciers   emulandice          glaciers
# 6       GrIS     bamber19         icesheets
# 7       GrIS  FittedISMIP              GrIS
# 8       GrIS   emulandice              GrIS
# 9        AIS      ipccar5         icesheets
# 10       AIS     bamber19         icesheets
# 11       AIS    deconto21               AIS
# 12       AIS   emulandice               AIS
# 13       AIS       larmip               AIS
# 14      EAIS      ipccar5         icesheets
# 15      EAIS     bamber19         icesheets
# 16      EAIS    deconto21               AIS
# 17      EAIS   emulandice               AIS
# 18      EAIS       larmip               AIS
# 19      WAIS      ipccar5         icesheets
# 20      WAIS      ipccar5         icesheets
# 21      WAIS    deconto21               AIS
# 22      WAIS   emulandice               AIS
# 23      WAIS       larmip               AIS
# 24       PEN   emulandice               AIS
# 25       PEN       larmip               AIS
# 26       SMB       larmip               AIS
# 27       LWS          ssp  landwaterstorage
#
#                                         DataFile
# 0           temperature.fair.temperature_gsat.nc
# 1      temperature.fair.temperature_oceantemp.nc
# 2            temperature.fair.temperature_ohc.nc
# 3            ocean.tlm.sterodynamics_globalsl.nc
# 4       ar5glaciers.ipccar5.glaciers_globalsl.nc
# 5    emuglaciers.emulandice.glaciers_globalsl.nc
# 6    bamber19.bamber19.icesheets_GIS_globalsl.nc
# 7        GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc
# 8            emuGrIS.emulandice.GrIS_globalsl.nc
# 9       ar5AIS.ipccar5.icesheets_AIS_globalsl.nc
# 10   bamber19.bamber19.icesheets_AIS_globalsl.nc
# 11       deconto21.deconto21.AIS_AIS_globalsl.nc
# 12             emuAIS.emulandice.AIS_globalsl.nc
# 13                 larmip.larmip.AIS_globalsl.nc
# 14     ar5AIS.ipccar5.icesheets_EAIS_globalsl.nc
# 15  bamber19.bamber19.icesheets_EAIS_globalsl.nc
# 16      deconto21.deconto21.AIS_EAIS_globalsl.nc
# 17        emuAIS.emulandice.AIS_EAIS_globalsl.nc
# 18            larmip.larmip.AIS_EAIS_globalsl.nc
# 19     ar5AIS.ipccar5.icesheets_WAIS_globalsl.nc
# 20  bamber19.bamber19.icesheets_WAIS_globalsl.nc
# 21      deconto21.deconto21.AIS_WAIS_globalsl.nc
# 22        emuAIS.emulandice.AIS_WAIS_globalsl.nc
# 23            larmip.larmip.AIS_WAIS_globalsl.nc
# 24         emuAIS.emulandice.AIS_PEN_globalsl.nc
# 25             larmip.larmip.AIS_PEN_globalsl.nc
# 26             larmip.larmip.AIS_SMB_globalsl.nc
# 27          lws.ssp.landwaterstorage_globalsl.nc

# %% [markdown]
# #### $\color{blue}{\text{Write nc data details to a file}}$

# %%
EXPDATE     = 221217
MODNO       = df.index.values;   # Number of datasets Module outputs
SCENARIO    = ['ssp126', 'ssp245', 'ssp585']; 
#        
file = open("ModuleData_Info_COUPLING-{arg1}.txt".format(arg1=EXPDATE), "w")
#
for val in MODNO: 
    for scenario in SCENARIO:
        #
        MODULE = df["Module"][val];  SUB_MODULE = df["sub_Module"][val]; COMP = df["Component"][val];
        # Skip if data is absent.
        if df["DataFile"][val] == 'XXX':
           continue 
        #
        # Pick the data files & Import nc file to dataframe. 
        dataFOLDER  = '/projects/kopp/facts-experiments/{arg2}/coupling.{arg1}/output/'.format(arg1=scenario,arg2=EXPDATE)
        dataFILE    = 'coupling.{arg1}.'.format(arg1=scenario) + df["DataFile"][val]
        d_nc        = xr.open_dataset(dataFOLDER + dataFILE)
        d_nc
    # Write infor of only last opend scenario file.     
    file.write( "DataFILE ==> "+str(df["DataFile"][val])+"\n"+ str(d_nc.dims) + "\n" + str(d_nc.data_vars)+ "\n" + str(d_nc.coords)+"\n"+"-------------"+"\n"+"\n" )
        #
file.close()

# %% [markdown]
# #### $\color{Red}{\text{Load Module data from ==> facts-experiments}}$

# %%
EXPDATE     = 221217
MODNO       = df.index.values;   # Number of datasets Module outputs
SCENARIO    = ['ssp126', 'ssp245', 'ssp585'];
#SCENARIO    = ['ssp119','ssp126', 'ssp245', 'ssp370', 'ssp585'];
YEAR        = 2100; # Percentile Year for the table.    
#
# Temp DF to store all .nc O/P.      
df_TEMP      = []
#        
for scenario in SCENARIO:
    # Define pd DF columns to append.
    PERCENTILE  = '%ile({arg2})'.format(arg2=scenario)
    percentile = np.nan
    df[PERCENTILE] = percentile
    df[PERCENTILE] = df[PERCENTILE].astype('object') 
    #
    for val in MODNO: 
        #
        MODULE = df["Module"][val];  SUB_MODULE = df["sub_Module"][val]; COMP = df["Component"][val]; DATAFILE = df["DataFile"][val];
        # Skip if data is absent.
        if df["DataFile"][val] == 'XXX':
           continue 
        #
        # Pick the data files & Import nc file to dataframe. 
        dataFOLDER  = '/projects/kopp/facts-experiments/{arg2}/coupling.{arg1}/output/'.format(arg1=scenario,arg2=EXPDATE)
        dataFILE    = 'coupling.{arg1}.'.format(arg1=scenario) + df["DataFile"][val]
        d_nc        = xr.open_dataset(dataFOLDER + dataFILE)
        d_nc
        #
        # Percentile calculation.
        percentList = [50, 17, 83]          #[50, 5, 17, 83, 95]
        # Find year index to pick SLC value
        Yind        = np.where(d_nc["years"].values == YEAR)[0][0]
        # 
        if SUB_MODULE == 'temperature':
            if  DATAFILE == 'temperature.fair.temperature_oceantemp.nc':
                    GMSL    = (d_nc["deep_ocean_temperature"][:,Yind,0].values)/1   
            elif DATAFILE == 'temperature.fair.temperature_ohc.nc':
                    GMSL    = (d_nc["ocean_heat_content"][:,Yind,0].values)/1   
            else:
                GMSL    = (d_nc["surface_temperature"][:,Yind,0].values)/1 
        else:
            GMSL    = (d_nc["sea_level_change"][:,Yind,0].values)/1       
        # Find Percentiles.
        pcntle = np.percentile(GMSL[:], percentList );    pcntle = np.around(pcntle,2)
        #
        # df.at[val,PERCENTILE] = [pcntle[0], pcntle[1],pcntle[2]]
        df.at[val,PERCENTILE] = f'{pcntle[0]:2.2f} ({pcntle[1]:2.2f} , {pcntle[2]:2.2f})' 
        # Print the OP.
print('GMSL Component Projections for ',d_nc["years"][Yind].values)    
#show(df)
df
# Out:
# GMSL Component Projections for  2100
#    Component       Module        sub_Module  \
# 0       GSAT         fair       temperature
# 1       GSAT         fair       temperature
# 2       GSAT         fair       temperature
# 3         TE          tlm     sterodynamics
# 4   Glaciers      ipccar5          glaciers
# 5   Glaciers   emulandice          glaciers
# 6       GrIS     bamber19         icesheets
# 7       GrIS  FittedISMIP              GrIS
# 8       GrIS   emulandice              GrIS
# 9        AIS      ipccar5         icesheets
# 10       AIS     bamber19         icesheets
# 11       AIS    deconto21               AIS
# 12       AIS   emulandice               AIS
# 13       AIS       larmip               AIS
# 14      EAIS      ipccar5         icesheets
# 15      EAIS     bamber19         icesheets
# 16      EAIS    deconto21               AIS
# 17      EAIS   emulandice               AIS
# 18      EAIS       larmip               AIS
# 19      WAIS      ipccar5         icesheets
# 20      WAIS      ipccar5         icesheets
# 21      WAIS    deconto21               AIS
# 22      WAIS   emulandice               AIS
# 23      WAIS       larmip               AIS
# 24       PEN   emulandice               AIS
# 25       PEN       larmip               AIS
# 26       SMB       larmip               AIS
# 27       LWS          ssp  landwaterstorage
#
#                                         DataFile  \
# 0           temperature.fair.temperature_gsat.nc
# 1      temperature.fair.temperature_oceantemp.nc
# 2            temperature.fair.temperature_ohc.nc
# 3            ocean.tlm.sterodynamics_globalsl.nc
# 4       ar5glaciers.ipccar5.glaciers_globalsl.nc
# 5    emuglaciers.emulandice.glaciers_globalsl.nc
# 6    bamber19.bamber19.icesheets_GIS_globalsl.nc
# 7        GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc
# 8            emuGrIS.emulandice.GrIS_globalsl.nc
# 9       ar5AIS.ipccar5.icesheets_AIS_globalsl.nc
# 10   bamber19.bamber19.icesheets_AIS_globalsl.nc
# 11       deconto21.deconto21.AIS_AIS_globalsl.nc
# 12             emuAIS.emulandice.AIS_globalsl.nc
# 13                 larmip.larmip.AIS_globalsl.nc
# 14     ar5AIS.ipccar5.icesheets_EAIS_globalsl.nc
# 15  bamber19.bamber19.icesheets_EAIS_globalsl.nc
# 16      deconto21.deconto21.AIS_EAIS_globalsl.nc
# 17        emuAIS.emulandice.AIS_EAIS_globalsl.nc
# 18            larmip.larmip.AIS_EAIS_globalsl.nc
# 19     ar5AIS.ipccar5.icesheets_WAIS_globalsl.nc
# 20  bamber19.bamber19.icesheets_WAIS_globalsl.nc
# 21      deconto21.deconto21.AIS_WAIS_globalsl.nc
# 22        emuAIS.emulandice.AIS_WAIS_globalsl.nc
# 23            larmip.larmip.AIS_WAIS_globalsl.nc
# 24         emuAIS.emulandice.AIS_PEN_globalsl.nc
# 25             larmip.larmip.AIS_PEN_globalsl.nc
# 26             larmip.larmip.AIS_SMB_globalsl.nc
# 27          lws.ssp.landwaterstorage_globalsl.nc
#
#                                          %ile(ssp126)  \
# 0                                  1.63 (1.35 , 1.99)
# 1                                  0.76 (0.53 , 1.09)
# 2   1673474282905716974944256.00 (1457585613797161...
# 3                            137.00 (112.00 , 171.00)
# 4                              92.00 (66.00 , 124.00)
# 5                              90.00 (69.00 , 109.00)
# 6                             127.00 (70.00 , 304.17)
# 7                               75.00 (58.00 , 97.17)
# 8                              53.00 (11.00 , 104.00)
# 9                             61.00 (-14.00 , 135.00)
# 10                             96.00 (-8.00 , 255.00)
# 11                             84.00 (64.00 , 109.00)
# 12                             84.00 (30.00 , 142.00)
# 13                            128.00 (52.83 , 261.17)
# 14                               8.00 (-2.00 , 19.00)
# 15                              5.00 (-34.00 , 41.00)
# 16                           -20.00 (-22.17 , -19.00)
# 17                              26.00 (-3.00 , 58.00)
# 18                              38.00 (12.00 , 94.17)
# 19                            52.00 (-12.00 , 116.00)
# 20                             89.50 (16.00 , 234.17)
# 21                            104.00 (87.00 , 128.00)
# 22                               45.00 (2.00 , 90.00)
# 23                            108.00 (59.00 , 194.17)
# 24                               11.00 (2.00 , 20.00)
# 25                                3.00 (0.00 , 11.00)
# 26                           -28.00 (-39.00 , -19.00)
# 27                              29.00 (17.00 , 42.00)
#
#                                          %ile(ssp245)  \
# 0                                  2.61 (2.19 , 3.12)
# 1                                  0.91 (0.63 , 1.33)
# 2   2108821334155340441190400.00 (1848619072094044...
# 3                            186.00 (154.00 , 227.17)
# 4                             115.00 (83.00 , 156.00)
# 5                             120.00 (99.83 , 142.00)
# 6                             127.00 (70.00 , 304.17)
# 7                             100.00 (79.00 , 124.00)
# 8                              77.00 (35.00 , 127.00)
# 9                             52.00 (-23.00 , 127.00)
# 10                             96.00 (-8.00 , 255.00)
# 11                             91.00 (71.00 , 114.00)
# 12                             80.00 (27.00 , 139.00)
# 13                            135.00 (54.00 , 286.00)
# 14                               7.00 (-3.00 , 18.00)
# 15                              5.00 (-34.00 , 41.00)
# 16                           -22.00 (-26.00 , -21.00)
# 17                              22.00 (-8.00 , 53.00)
# 18                             42.00 (14.00 , 108.00)
# 19                            45.00 (-20.00 , 109.00)
# 20                             89.50 (16.00 , 234.17)
# 21                            114.00 (97.00 , 135.00)
# 22                               47.00 (4.00 , 92.00)
# 23                            117.00 (64.00 , 212.00)
# 24                               11.00 (1.00 , 20.00)
# 25                                3.00 (0.00 , 12.17)
# 26                           -34.00 (-47.00 , -23.00)
# 27                              30.00 (17.00 , 44.00)
#
#                                          %ile(ssp585)
# 0                                  4.66 (3.96 , 5.55)
# 1                                  1.24 (0.85 , 1.81)
# 2   2996262846488100470784000.00 (2632352218228153...
# 3                            286.00 (240.00 , 347.17)
# 4                            160.00 (113.00 , 218.00)
# 5                            176.00 (151.00 , 201.00)
# 6                            221.50 (102.00 , 589.17)
# 7                            139.00 (112.00 , 176.00)
# 8                             124.00 (82.00 , 176.00)
# 9                             35.50 (-42.00 , 113.00)
# 10                            201.50 (21.00 , 574.34)
# 11                           337.00 (194.00 , 526.00)
# 12                             82.50 (28.00 , 139.17)
# 13                            151.00 (54.00 , 341.17)
# 14                               5.00 (-5.00 , 16.00)
# 15                            22.00 (-38.00 , 116.00)
# 16                            147.00 (49.00 , 295.00)
# 17                             15.00 (-13.00 , 46.00)
# 18                             49.00 (16.00 , 137.00)
# 19                             30.00 (-36.00 , 97.00)
# 20                            176.50 (29.00 , 471.17)
# 21                           190.00 (148.00 , 246.00)
# 22                              54.00 (13.00 , 98.17)
# 23                            135.00 (73.00 , 251.17)
# 24                               12.00 (2.00 , 21.00)
# 25                                4.00 (0.00 , 16.00)
# 26                           -47.00 (-66.00 , -31.00)
# 27                              29.00 (16.00 , 41.00)

# %%
df.to_excel(r'Table_CheckModule_COUPLING_GMSL-Proj_2100-{arg1}.xlsx'.format(arg1=EXPDATE), index=False)
