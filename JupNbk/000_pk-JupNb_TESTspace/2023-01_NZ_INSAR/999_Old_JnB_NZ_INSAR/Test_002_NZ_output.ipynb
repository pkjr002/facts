# %% [markdown]
# # <font color=black> __________________________________________________________________________________________________ </font>
# # <font color=blue> Get <font color=green> **/EXP/output** </font> file details </font>

# %% [markdown]
# ##### <font color=blue> Get the  <font color=green> **NZrerun.OG.total.workflow.wf1e.global.nc** </font> file </font>

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib as lib
#

PATH        = '/scratch/pk695/FACTS/002_fork/facts/experiments-pkjr002/NZrerun.OG/output/'
FILENAME1   = 'NZrerun.OG.total.workflow.wf1e.local.nc'
#
d_nc        = xr.open_dataset(PATH + FILENAME1)
d_nc.lat

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib as lib
#

PATH        = '/scratch/pk695/FACTS/002_fork/facts/experiments-pkjr002/NZrerun.OG.NYC.NZ/output/'
FILENAME1   = 'NZrerun.OG.NYC.NZ.total.workflow.wf1e.local.nc'
#
d_nc        = xr.open_dataset(PATH + FILENAME1)
# d_nc.lat

# %% [markdown]
# # <font color=black> __________________________________________________________________________________________________ </font>
# # <font color=blue> Get <font color=red> **GREGS NZ** </font> output file details </font>

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib as plt
#

PATH        = '/projects/kopp/ggg46/nz_projections/regional/full_sample_workflows/wf_1e/ssp585/'
FILENAME1   = 'total-workflow.nc'
#
d_nc        = xr.open_dataset(PATH + FILENAME1)
lat = d_nc.lat
lon = d_nc.lon
# d_nc

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# longitude = d_nc['lon'].to_dataframe().values.tolist()
# latitude = d_nc['lat'].to_dataframe().values.tolist()

longitude = d_nc['lon'].to_dataframe().values
latitude = d_nc['lat'].to_dataframe().values

# Latitude and longitude values for NZ
min_lon = -180.0
max_lon = 180.0
min_lat = -50.0
max_lat = 60.0

# Create the map
m = Basemap(projection='merc', llcrnrlat=min_lat, urcrnrlat=max_lat, llcrnrlon=min_lon, urcrnrlon=max_lon, resolution='c')
m.drawcoastlines()
m.fillcontinents(color='lightgray', lake_color='lightblue')
m.scatter(longitude, latitude, latlon=True, marker='.', color='red', zorder=5)

plt.title("Latitude and Longitude Plot")


plt.show()
