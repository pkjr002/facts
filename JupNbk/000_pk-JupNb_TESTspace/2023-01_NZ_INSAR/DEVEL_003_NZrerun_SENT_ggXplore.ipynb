# %% [markdown]
# ### <font color=black> IMPORT:: <font color=blue> **py modules** </font> </font>

# %%
import numpy as np
import pandas as pd
import xarray as xr
from mpl_toolkits.basemap import Basemap
import glob
import os
import shutil
import re
import cartopy
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
# %matplotlib inline
#
PD=os.getcwd(); PD
# Out:
# '/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR'

# %% [markdown]
# ### <font color=black> **====================================================================** </font>
# ### <font color=black> DATA:: <font color=blue> EXPLORE </font>

# %%
#path1='/scratch/pk695/FACTS/NZrerun-pk695/local-pk695/000_full_sample_components/NZrerun1.ssp119c.ocean.tlm.sterodynamics_localsl.nc'
path1='/projects/kopp/ggg46/nz_projections/regional/full_sample_components/glaciers-ar5-glaciersgmip2-ssp119_localsl.nc'
d_nc1=xr.open_dataset(path1)
d_nc1
# Out:
# <xarray.Dataset>
# Dimensions:           (samples: 20000, years: 29, locations: 7435)
# Coordinates:
#   * years             (years) int64 2020 2030 2040 2050 ... 2270 2280 2290 2300
#   * locations         (locations) int64 0 1 2 3 4 5 ... 7430 7431 7432 7433 7434
#   * samples           (samples) int64 0 1 2 3 4 ... 19996 19997 19998 19999
# Data variables:
#     sea_level_change  (samples, years, locations) float32 ...
#     lat               (locations) float64 ...
#     lon               (locations) float64 ...
# Attributes:
#     description:  Local SLR contributions from glaciers according to AR5 work...
#     history:      Created Fri Aug 27 17:45:26 2021
#     source:       SLR Framework: AR5 workflow
#     scenario:     ssp119
#     baseyear:     2005

# %%
#d_nc1.keys()

# %%
#path1='/projects/kopp/ggg46/nz_projections/regional/full_sample_components/oceandynamics-tlm-oceandynamics-ssp119_localsl.nc'
path1='/projects/kopp/ggg46/nz_projections/regional/dist_components/oceandynamics-tlm-oceandynamics-ssp119_localsl.nc'
d_nc1=xr.open_dataset(path1)
d_nc1
# Out:
# <xarray.Dataset>
# Dimensions:           (samples: 2000, years: 15, locations: 8179)
# Coordinates:
#   * years             (years) int64 2005 2020 2030 2040 ... 2120 2130 2140 2150
#   * locations         (locations) int64 3000000000 3000000010 ... 3000081780
#   * samples           (samples) int64 0 1 2 3 4 5 ... 1995 1996 1997 1998 1999
# Data variables:
#     sea_level_change  (samples, years, locations) float32 ...
#     lat               (locations) float64 ...
#     lon               (locations) float64 ...
# Attributes:
#     description:  Local SLR contributions from vertical land motion according...
#     history:      Created Sun Feb 19 14:54:56 2023
#     source:       SLR Framework: NZInsarGPS workflow
#     scenario:     NA
#     baseyear:     2005

# %%
path='/projects/kopp/ggg46/nz_projections/regional/dist_components'
os.chdir(path)
ncfile = sorted(os.listdir())
# sorted_ncfile = sorted(ncfile, key=lambda x: x.split('.')[2])
# ncfile=sorted_ncfile

nosfiles = len(ncfile)
print(f"There are a TOTAL of {nosfiles} files in the directory {path}.\n")

keyword='win0'; print(f"Files belonging to {keyword} ")
numfile=0 ; numfile1=0
for nc in ncfile:
    if keyword in nc:
        #print(nc) 
        numfile+=1
    else:
        print(nc)
        numfile1+=1 

print(f"\n There are {numfile} files belonging to {keyword} in the directory.\n")
print(f"\n There are {numfile1} files not belonging to {keyword} in the directory.\n")
# Out:
# There are a TOTAL of 99 files in the directory /projects/kopp/ggg46/nz_projections/regional/dist_components.
#
# Files belonging to win0
# glaciers-ar5-glaciersgmip2-ssp119_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp126_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp245_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp370_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp585_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp119_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp126_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp245_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp370_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp585_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp119_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp126_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp245_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp370_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp585_GIS_localsl.nc
# icesheets-ar5-icesheets-ssp119_AIS_localsl.nc
# ...

# %% [markdown]
# ### <font color=black> **====================================================================** </font>
# ### <font color=black> DATA:: <font color=blue> gregs Final Submitted Data </font>
# <p color=black> ( 000_generate_confidence_level_output_files ) </p>

# %%
# Amarel File
#path1="/projects/kopp/ggg46/nz_projections/regional/confidence_output_files/medium_confidence/ssp585/AIS_ssp585_medium_confidence_rates.nc"
# Submitted data file
path1='/scratch/pk695/FACTS/NZrerun-pk695/GREGS_data2NZ/medium_confidence/ssp585/AIS_ssp585_medium_confidence_rates.nc'
d_nc1=xr.open_dataset(path1)
d_nc1
# Out:
# <xarray.Dataset>
# Dimensions:                (locations: 7435, years: 14, quantiles: 107)
# Coordinates:
#   * locations              (locations) int32 0 1 2 3 4 ... 7431 7432 7433 7434
#   * years                  (years) int32 2020 2030 2040 2050 ... 2130 2140 2150
#   * quantiles              (quantiles) float64 0.0 0.001 0.005 ... 0.999 1.0
# Data variables:
#     lat                    (locations) float32 ...
#     lon                    (locations) float32 ...
#     sea_level_change_rate  (quantiles, years, locations) float32 ...
# Attributes:
#     description:  Combined confidence output file for AR6 sea-level change pr...
#     history:      Created Tue Sep 28 17:06:27 2021
#     source:       Files Combined: /projects/kopp/ggg46/nz_projections/regiona...

# %%
path2="/scratch/pk695/FACTS/NZrerun-pk695/GREGS_data2NZ/medium_confidence/ssp585/AIS_ssp585_medium_confidence_values.nc"
d_nc2=xr.open_dataset(path2)
d_nc2
# Out:
# <xarray.Dataset>
# Dimensions:           (locations: 7435, quantiles: 107, years: 14)
# Coordinates:
#   * years             (years) int32 2020 2030 2040 2050 ... 2120 2130 2140 2150
#   * locations         (locations) int32 0 1 2 3 4 5 ... 7430 7431 7432 7433 7434
#   * quantiles         (quantiles) float64 0.0 0.001 0.005 ... 0.995 0.999 1.0
# Data variables:
#     lat               (locations) float32 ...
#     lon               (locations) float32 ...
#     sea_level_change  (quantiles, years, locations) float32 ...
# Attributes:
#     description:  Combined confidence output file for AR6 sea-level change pr...
#     history:      Created Tue Sep 28 17:04:48 2021
#     source:       Files Combined: /projects/kopp/ggg46/nz_projections/regiona...

# %% [markdown]
# <span style="color:green">
# <p color=black> In the files that greg submitted, the <strong> rate </strong> files are generated using <strong> regional pboxes_rates </strong> .</p>
# <p color=black> Similarly the <strong> values </strong> files are generated using <strong> regional pboxes </strong> .</p>
# </span>

# %% [markdown]
# ### <font color=black> **====================================================================** </font>
# ### <font color=black> DATA:: <font color=blue> regional pboxes </font>

# %%
path="/projects/kopp/ggg46/nz_projections/regional/pboxes/pb_1e/ssp585/glaciers-ipccar6-gmipemuglaciers-ssp585_localsl.nc"
d_nc=xr.open_dataset(path)
d_nc
# Out:
# <xarray.Dataset>
# Dimensions:           (quantiles: 107, years: 9, locations: 7435)
# Coordinates:
#   * years             (years) int64 2020 2030 2040 2050 2060 2070 2080 2090 2100
#   * locations         (locations) int64 0 1 2 3 4 5 ... 7430 7431 7432 7433 7434
#   * quantiles         (quantiles) float64 0.0 0.001 0.005 ... 0.995 0.999 1.0
# Data variables:
#     sea_level_change  (quantiles, years, locations) float32 ...
#     lat               (locations) float64 ...
#     lon               (locations) float64 ...
# Attributes:
#     description:  Local SLR contributions from glaciers according to GMIP2 em...
#     history:      Created Fri Aug 27 18:20:01 2021
#     source:       SLR Framework: AR5 workflow
#     scenario:     ssp585
#     baseyear:     2005

# %% [markdown]
# ### <font color=black> **====================================================================** </font>
# ### <font color=black> DATA:: <code style="background:lightgrey;color:blue"> full_sample_components
# </code> </font>

# %% [markdown]
# <font color=black>
# It appears that the <code style="background:lightgrey;color:black"> full_sample_components</code> folder, the data was added from running individual bash scripts
# </font>

# %% [markdown]
# ### <font color=black> LIST:: <font color=blue> single ssp unique files </font>
# <p> Count the total number of files in the <code style="background:lightgrey;color:black">full_sample_components</code>
# folder and also count per scenario.
# </p>

# %% [markdown]
# ### <font color=black> **...........................** </font>
# ### <font color=black> gg DATA:: <code style="background:lightgrey;color:blue"> full_sample_components
# </code> </font>

# %%
path='/projects/kopp/ggg46/nz_projections/regional/full_sample_components'
# path='/scratch/pk695/FACTS/NZrerun-pk695/local-pk695/full_sample_components'
os.chdir(path)
ncfile = sorted(os.listdir())
# sorted_ncfile = sorted(ncfile, key=lambda x: x.split('.')[2])
# ncfile=sorted_ncfile

nosfiles = len(ncfile)
print(f"There are {nosfiles} files in the directory {path}.\n")

keyword='ssp'; print(f"Files belonging to {keyword} ")
numfile=0
for nc in ncfile:
    if keyword in nc:
        print(nc) 
        numfile+=1
    # else:
        # print(nc) 
print(f"\n There are {numfile} files belonging to {keyword} in the directory.\n")
# Out:
# There are 185 files in the directory /projects/kopp/ggg46/nz_projections/regional/full_sample_components.
#
# Files belonging to ssp
# glaciers-ar5-glaciersgmip2-ssp119_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp126_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp245_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp370_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp585_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp119_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp126_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp245_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp370_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp585_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp119_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp126_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp245_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp370_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp585_GIS_localsl.nc
# icesheets-ar5-icesheets-ssp119_AIS_localsl.nc
# ...

# %% [markdown]
# ### <font color=black> **...........................** </font>
# ### <font color=black> pkjr002 DATA:: <code style="background:lightgrey;color:blue"> full_sample_components
# </code> </font>

# %%
# path='/projects/kopp/ggg46/nz_projections/regional/full_sample_components'
path='/scratch/pk695/FACTS/NZrerun-pk695/local-pk695/full_sample_components'
os.chdir(path)
ncfile = sorted(os.listdir())
sorted_ncfile = sorted(ncfile, key=lambda x: x.split('.')[2])
ncfile=sorted_ncfile

nosfiles = len(ncfile)
print(f"There are {nosfiles} files in the directory {path}.\n")

keyword='ssp'; print(f"Files belonging to {keyword} ")
numfile=0
for nc in ncfile:
    if keyword in nc:
        print(nc) 
        numfile+=1
    # else:
        # print(nc) 
print(f"\n There are {numfile} files belonging to {keyword} in the directory.\n")
# Out:
# There are 77 files in the directory /scratch/pk695/FACTS/NZrerun-pk695/local-pk695/full_sample_components.
#
# Files belonging to ssp
# NZrerun1.ssp119c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp126c1.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp245c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp370c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp585c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp119c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp126c1.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp245c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp370c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp585c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp119c.ar5AIS.ipccar5.icesheets_EAIS_localsl.nc
# NZrerun1.ssp119c.ar5AIS.ipccar5.icesheets_WAIS_localsl.nc
# NZrerun1.ssp245c.ar5AIS.ipccar5.icesheets_EAIS_localsl.nc
# ...

# %% [markdown]
# <p>
# Note that there are 5 VLM files in the above list
#
# MISSING FILES compared to gg list <br>
# glaciers-ar5-glaciersgmip2-ssp126_localsl.nc,
# glaciers-ipccar6-gmipemuglaciers-ssp126_localsl.nc,
# icesheets-ar5-icesheets-ssp119_AIS_localsl.nc,
# icesheets-ar5-icesheets-ssp119_GIS_localsl.nc,
# icesheets-ar5-icesheets-ssp126_AIS_localsl.nc,
# icesheets-ar5-icesheets-ssp126_EAIS_localsl.nc,
# icesheets-ar5-icesheets-ssp126_GIS_localsl.nc,
# icesheets-ar5-icesheets-ssp126_WAIS_localsl.nc,
# icesheets-ar5-icesheets-ssp245_AIS_localsl.nc,
# icesheets-ar5-icesheets-ssp245_GIS_localsl.nc,
# icesheets-ar5-icesheets-ssp370_AIS_localsl.nc,
# icesheets-ar5-icesheets-ssp370_GIS_localsl.nc,
# icesheets-ar5-icesheets-ssp585_AIS_localsl.nc,
# icesheets-ar5-icesheets-ssp585_GIS_localsl.nc,
# icesheets-dp20-icesheet-ssp126_AIS_localsl.nc,
# icesheets-dp20-icesheet-ssp126_EAIS_localsl.nc,
# icesheets-dp20-icesheet-ssp126_WAIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp126_AIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp126_EAIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp126_GIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp126_WAIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp245_AIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp245_EAIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp245_GIS_localsl.nc,
# icesheets-ipccar6-bambericesheet-ssp245_WAIS_localsl.nc,
# icesheets-ipccar6-ismipemuicesheet-ssp126_AIS_localsl.nc,
# icesheets-ipccar6-ismipemuicesheet-ssp126_EAIS_localsl.nc,
# icesheets-ipccar6-ismipemuicesheet-ssp126_GIS_localsl.nc,
# icesheets-ipccar6-ismipemuicesheet-ssp126_WAIS_localsl.nc,
# </p>

# %% [markdown]
# ### <font color=black> **====================================================================** </font>
# ### <font color=black> DATA:: <code style="background:lightgrey;color:blue"> dist_components
# </code> </font>

# %% [markdown]
# ### <font color=black> **...........................** </font>
# ### <font color=black> gg  DATA:: <code style="background:lightgrey;color:blue"> dist_components
# </code> </font>

# %%
path='/projects/kopp/ggg46/nz_projections/regional/dist_components'
# path='/scratch/pk695/FACTS/NZrerun-pk695/local-pk695/full_sample_components'
os.chdir(path)
ncfile = sorted(os.listdir())
# sorted_ncfile = sorted(ncfile, key=lambda x: x.split('.')[2])
# ncfile=sorted_ncfile

nosfiles = len(ncfile)
print(f"There are {nosfiles} files in the directory {path}.\n")

keyword='ssp'; print(f"Files belonging to {keyword} ")
numfile=0
for nc in ncfile:
    if keyword in nc:
        print(nc) 
        numfile+=1
    # else:
        # print(nc) 
print(f"\n There are {numfile} files belonging to {keyword} in the directory.\n")
# Out:
# There are 99 files in the directory /projects/kopp/ggg46/nz_projections/regional/dist_components.
#
# Files belonging to ssp
# glaciers-ar5-glaciersgmip2-ssp119_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp126_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp245_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp370_localsl.nc
# glaciers-ar5-glaciersgmip2-ssp585_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp119_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp126_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp245_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp370_localsl.nc
# glaciers-ipccar6-gmipemuglaciers-ssp585_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp119_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp126_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp245_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp370_GIS_localsl.nc
# icesheets-FittedISMIP-icesheets-ssp585_GIS_localsl.nc
# icesheets-ar5-icesheets-ssp119_AIS_localsl.nc
# ...

# %% [markdown]
# ### <font color=black> **...........................** </font>
# ### <font color=black> pkjr  DATA:: <code style="background:lightgrey;color:blue"> dist_components
# </code> </font>

# %%
# path='/projects/kopp/ggg46/nz_projections/regional/full_sample_components'
path='/scratch/pk695/FACTS/NZrerun-pk695/local-pk695/dist_components'
os.chdir(path)
ncfile = sorted(os.listdir())
sorted_ncfile = sorted(ncfile, key=lambda x: x.split('.')[2])
ncfile=sorted_ncfile

nosfiles = len(ncfile)
print(f"There are {nosfiles} files in the directory {path}.\n")

keyword='ssp'; print(f"Files belonging to {keyword} ")
numfile=0
for nc in ncfile:
    if keyword in nc:
        print(nc) 
        numfile+=1
    # else:
        # print(nc) 
print(f"\n There are {numfile} files belonging to {keyword} in the directory.\n")
# Out:
# There are 60 files in the directory /scratch/pk695/FACTS/NZrerun-pk695/local-pk695/dist_components.
#
# Files belonging to ssp
# NZrerun1.ssp119c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp126c1.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp245c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp370c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp585c.GrIS1f.FittedISMIP.GrIS_GIS_localsl.nc
# NZrerun1.ssp119c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp126c1.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp245c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp370c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp585c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc
# NZrerun1.ssp119c.ar5AIS.ipccar5.icesheets_EAIS_localsl.nc
# NZrerun1.ssp119c.ar5AIS.ipccar5.icesheets_WAIS_localsl.nc
# NZrerun1.ssp245c.ar5AIS.ipccar5.icesheets_EAIS_localsl.nc
# ...

# %% [markdown]
# <p>
# REMEMBER tha there are 5 files which belong to VLM in out dir. Greg has just one.<br>
# AIS needs to be combined for 4 WF, thus 4 (WAIS) extra files. <br>
# Toatal files to compare to gregs:: 50 <br>
# <br>
# These files are missing from dist_components pf pkjr, <br>
# icesheets-ar5-icesheets-ssp126_AIS_localsl.nc <br>
# icesheets-ipccar6-bambericesheet-ssp245_AIS_localsl.nc <br>
# icesheets-ipccar6-bambericesheet-ssp245_GIS_localsl.nc <br>
# <br>
# These Files are extra in pkjr <br>
# EXTRA:: <br>
# NZrerun1.ssp119c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc <br>
# NZrerun1.ssp126c1.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc <br>
# NZrerun1.ssp245c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc <br>
# NZrerun1.ssp370c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc <br>
# NZrerun1.ssp585c.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc <br>
# NZrerun1.ssp119c.ar5AIS.ipccar5.icesheets_WAIS_localsl.nc <br>
# NZrerun1.ssp245c.ar5AIS.ipccar5.icesheets_WAIS_localsl.nc <br>
# NZrerun1.ssp370c.ar5AIS.ipccar5.icesheets_WAIS_localsl.nc <br>
# NZrerun1.ssp585c.ar5AIS.ipccar5.icesheets_WAIS_localsl.nc <br>
#
#
#
#
#
# </p>

# %% [markdown]
# ### <font color=black> **====================================================================** </font>
# ### <font color=black> DATA:: <code style="background:lightgrey;color:blue"> dist_components</code> vs <code style="background:lightgrey;color:blue"> full_sample_components </code> </font>

# %%
path1='/projects/kopp/ggg46/nz_projections/regional/full_sample_workflows/wf_1e/ssp119/total-workflow.nc'
d_nc1=xr.open_dataset(path1)
d_nc1
# Out:
# <xarray.Dataset>
# Dimensions:           (samples: 20000, years: 9, locations: 7435)
# Coordinates:
#   * years             (years) int64 2020 2030 2040 2050 2060 2070 2080 2090 2100
#   * locations         (locations) int64 0 1 2 3 4 5 ... 7430 7431 7432 7433 7434
#   * samples           (samples) int64 0 1 2 3 4 ... 19996 19997 19998 19999
# Data variables:
#     sea_level_change  (samples, years, locations) float32 ...
#     lat               (locations) float64 ...
#     lon               (locations) float64 ...
# Attributes:
#     description:  Total sea-level change for workflow
#     history:      Created Mon Aug 30 13:35:16 2021
#     source:       FACTS: Post-processed total among available contributors: i...

# %%
path1='/projects/kopp/ggg46/nz_projections/regional/dist_workflows/wf_1e/ssp119/total-workflow.nc'
d_nc1=xr.open_dataset(path1)
d_nc1
# Out:
# <xarray.Dataset>
# Dimensions:           (quantiles: 107, years: 9, locations: 7435)
# Coordinates:
#   * years             (years) int64 2020 2030 2040 2050 2060 2070 2080 2090 2100
#   * locations         (locations) int64 0 1 2 3 4 5 ... 7430 7431 7432 7433 7434
#   * quantiles         (quantiles) float64 0.0 0.001 0.005 ... 0.995 0.999 1.0
# Data variables:
#     sea_level_change  (quantiles, years, locations) float32 ...
#     lat               (locations) float64 ...
#     lon               (locations) float64 ...
# Attributes:
#     description:  Total sea-level change for workflow
#     history:      Created Mon Aug 30 13:35:16 2021
#     source:       FACTS: Post-processed total among available contributors: i...

# %% [markdown]
# ### <font color=black> **====================================================================** </font>
# ### <font color=black> DATA:: <code style="background:lightgrey;color:blue"> Rate Files </code> </font>

# %%
path1='/projects/kopp/ggg46/nz_projections/regional/full_sample_components_rates/glaciers-ar5-glaciersgmip2-ssp119_localsl_rates.nc'
d_nc1=xr.open_dataset(path1)
d_nc1
# Out:
# <xarray.Dataset>
# Dimensions:                (samples: 20000, years: 29, locations: 7435)
# Coordinates:
#   * years                  (years) int64 2020 2030 2040 2050 ... 2280 2290 2300
#   * locations              (locations) int64 0 1 2 3 4 ... 7431 7432 7433 7434
#   * samples                (samples) int64 0 1 2 3 4 ... 19996 19997 19998 19999
# Data variables:
#     sea_level_change_rate  (samples, years, locations) float32 ...
#     lat                    (locations) float64 ...
#     lon                    (locations) float64 ...
# Attributes:
#     description:  Local SLR contributions from glaciers according to AR5 work...
#     history:      Created Fri Aug 27 17:45:26 2021
#     source:       SLR Framework: AR5 workflow
#     scenario:     ssp119
#     baseyear:     2005
