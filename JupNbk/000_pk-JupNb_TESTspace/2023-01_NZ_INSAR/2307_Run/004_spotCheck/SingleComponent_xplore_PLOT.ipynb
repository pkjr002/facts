# %% [markdown]
# <p style="border: 2px solid black; padding: 5px; font-size: 16pt; color: blue; font-family: 'Times New Roman';background-color: yellow;">
#     PLOT ::  &nbsp
#             <span style="color: black;"><b>Single component Projection</b></span> &nbsp
#     *.nc
# </p>

# %%
import matplotlib.pyplot as plt
import SingleComponent_xplore_FUN as fn
#
options = {'xlab': 'year', 'ylab': 'Sea Level Rise (m)', 'font': 8, 'decimal' : 1,
           'x_min': 2020, 'x_max': 2150,  'x_int': 10, 'y_min': -.2, 'y_max': 1.01,  'y_int': 1,
           'yrST' : 2020, 'yrEN' : 2150, 'grid' : 'no', 'tick_pos' : 'regular'}
fig, axes = plt.subplots(2, 2, figsize=(15, 8)); plt.subplots_adjust(wspace=0.35, hspace=0.5)
#
ssp = 'ssp585'; stnIDX = 0;  WF='wf_1e';region = 'regional'
#                                                                                                                                                      
file=[f'/scratch/pk695/FACTS/002_fork/facts/experimentsNZ/nzRE.2309/ssp585/output/ssp585.GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc']
#
fn.showFIG(axes[0,0],file[0],stnIDX,region,ssp,options)
axes[0,1].axis('off');
axes[1,0].axis('off');
axes[1, 1].axis('off');
