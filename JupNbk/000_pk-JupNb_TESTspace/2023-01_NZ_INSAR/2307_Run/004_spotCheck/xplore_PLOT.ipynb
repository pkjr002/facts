# %% [markdown]
# <p style="border: 2px solid black; padding: 5px; font-size: 14pt; color: blue; font-family: 'Times New Roman';background-color: yellow;">
#     PLOT ::  &nbsp
#             <span style="color: black;"><b>NZ_ReRun_2307 / FACTS_1.0_NZ_pk_updatedVLM / medium_confidence</b></span> &nbsp
#     *.nc
# </p>

# %%
import matplotlib.pyplot as plt
import xplore_FUN as fn
#
options = {'xlab': 'year', 'ylab': 'Sea Level Rise (m)', 'font': 8, 'decimal' : 1,
           'x_min': 2020, 'x_max': 2150,  'x_int': 10, 'y_min': -1, 'y_max': 3.51,  'y_int': 1,
           'yrST' : 2020, 'yrEN' : 2150, 'grid' : 'no', 'tick_pos' : 'regular'}
#
fig, axes = plt.subplots(2, 2, figsize=(15, 8)); plt.subplots_adjust(wspace=0.35, hspace=0.5)
#
ssp = 'ssp585'; stnIDX = 7000; region = 'regional'
#
Ffolder=f'../003_Public/NZ_ReRun_2307'
Ffile='total'

file=[f'{Ffolder}/{region}_NOVLM/FACTS_1.0_NZ_pk_updatedVLM/medium_confidence/{ssp}/{Ffile}_{ssp}_medium_confidence_values.nc',
      f'{Ffolder}/{region}/FACTS_1.0_NZ_pk_updatedVLM/medium_confidence/{ssp}/{Ffile}_{ssp}_medium_confidence_values.nc',
      f'{Ffolder}/{region}/FACTS_1.0_NZ_pk_updatedVLM/medium_confidence/{ssp}/verticallandmotion_{ssp}_medium_confidence_values.nc']
#
fn.showFIG(axes[0,0],file[0],stnIDX,region,ssp,options)
fn.showFIG(axes[0,1],file[1],stnIDX,region,ssp,options)
fn.showFIG(axes[1,0],file[2],stnIDX,region,ssp,options)
axes[1, 1].axis('off');

# %%
import matplotlib.pyplot as plt
import xplore_FUN as fn
#
options = {'xlab': 'year', 'ylab': 'Sea Level Rise (m)', 'font': 8, 'decimal' : 1,
           'x_min': 2020, 'x_max': 2150,  'x_int': 10, 'y_min': -1, 'y_max': 3.51,  'y_int': 1,
           'yrST' : 2020, 'yrEN' : 2150, 'grid' : 'no', 'tick_pos' : 'regular'}
#
fig, axes = plt.subplots(2, 2, figsize=(15, 8)); plt.subplots_adjust(wspace=0.35, hspace=0.5)
#
ssp = 'ssp370'; stnIDX = 7000; region = 'regional'
#
Ffolder=f'../003_Public/NZ_ReRun_2307'
Ffile='total'

file=[f'{Ffolder}/{region}_NOVLM/FACTS_1.0_NZ_pk_updatedVLM/medium_confidence/{ssp}/{Ffile}_{ssp}_medium_confidence_values.nc',
      f'{Ffolder}/{region}/FACTS_1.0_NZ_pk_updatedVLM/medium_confidence/{ssp}/{Ffile}_{ssp}_medium_confidence_values.nc',
      f'{Ffolder}/{region}/FACTS_1.0_NZ_pk_updatedVLM/medium_confidence/{ssp}/verticallandmotion_{ssp}_medium_confidence_values.nc']
#
fn.showFIG(axes[0,0],file[0],stnIDX,region,ssp,options)
fn.showFIG(axes[0,1],file[1],stnIDX,region,ssp,options)
fn.showFIG(axes[1,0],file[2],stnIDX,region,ssp,options)
axes[1, 1].axis('off');

# %% [markdown]
# <p style="border: 2px solid black; padding: 5px; font-size: 16pt; color: blue; font-family: 'Times New Roman';background-color: yellow;">
#     PLOT ::  &nbsp
#             <span style="color: black;"><b>003_Pbox</b></span> &nbsp
#     *.nc
# </p>

# %%
#
options = {'xlab': 'year', 'ylab': 'Sea Level Rise (m)', 'font': 8, 'decimal' : 1,
           'x_min': 2020, 'x_max': 2100,  'x_int': 10, 'y_min': -.2, 'y_max': 1.01,  'y_int': 1,
           'yrST' : 2020, 'yrEN' : 2100, 'grid' : 'no', 'tick_pos' : 'regular'}
fig, axes = plt.subplots(2, 2, figsize=(15, 8)); plt.subplots_adjust(wspace=0.35, hspace=0.5)
#
ssp = 'ssp585'; stnIDX = 7000; 
#
file=[f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE_NOVLM/3_pbox/pb_1e/{ssp}/total-workflow.nc',
      f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE/3_pbox/pb_1e/{ssp}/total-workflow.nc',
      f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE/3_pbox/pb_1e/{ssp}/{ssp}.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc']
#
fn.showFIG(axes[0,0],file[0],stnIDX,region,ssp,options)
fn.showFIG(axes[0,1],file[1],stnIDX,region,ssp,options)
fn.showFIG(axes[1,0],file[2],stnIDX,region,ssp,options)
axes[1, 1].axis('off');

# %% [markdown]
# <p style="border: 2px solid black; padding: 5px; font-size: 16pt; color: blue; font-family: 'Times New Roman';background-color: yellow;">
#     PLOT ::  &nbsp
#             <span style="color: black;"><b>2_workflow_quantiles</b></span> &nbsp
#     *.nc
# </p>

# %%
#
options = {'xlab': 'year', 'ylab': 'Sea Level Rise (m)', 'font': 8, 'decimal' : 1,
           'x_min': 2020, 'x_max': 2100,  'x_int': 10, 'y_min': -.2, 'y_max': 1.01,  'y_int': 1,
           'yrST' : 2020, 'yrEN' : 2100, 'grid' : 'no', 'tick_pos' : 'regular'}
fig, axes = plt.subplots(2, 2, figsize=(15, 8)); plt.subplots_adjust(wspace=0.35, hspace=0.5)
#
ssp = 'ssp370'; stnIDX = 7000;  WF='wf_1e'
#                                                                                                                                                      
file=[f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE_NOVLM/2_workflow_quantiles/{WF}/{ssp}/{ssp}.total.workflow.{WF[:2]}{WF[3:]}NOVLM.local.nc',
      f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE/2_workflow_quantiles/{WF}/{ssp}/{ssp}.total.workflow.{WF[:2]}{WF[3:]}.local.nc',
      f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE/2_workflow_quantiles/{WF}/{ssp}/{ssp}.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc']
#
fn.showFIG(axes[0,0],file[0],stnIDX,region,ssp,options)
fn.showFIG(axes[0,1],file[1],stnIDX,region,ssp,options)
fn.showFIG(axes[1,0],file[2],stnIDX,region,ssp,options)
axes[1, 1].axis('off');

# %%
#
options = {'xlab': 'year', 'ylab': 'Sea Level Rise (m)', 'font': 8, 'decimal' : 1,
           'x_min': 2020, 'x_max': 2100,  'x_int': 10, 'y_min': -.2, 'y_max': 1.01,  'y_int': 1,
           'yrST' : 2020, 'yrEN' : 2100, 'grid' : 'no', 'tick_pos' : 'regular'}
fig, axes = plt.subplots(2, 2, figsize=(15, 8)); plt.subplots_adjust(wspace=0.35, hspace=0.5)
#
ssp = 'ssp585'; stnIDX = 7000;  WF='wf_1e'
#                                                                                                                                                      
file=[f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE_NOVLM/2_workflow_quantiles/{WF}/{ssp}/{ssp}.total.workflow.{WF[:2]}{WF[3:]}NOVLM.local.nc',
      f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE/2_workflow_quantiles/{WF}/{ssp}/{ssp}.total.workflow.{WF[:2]}{WF[3:]}.local.nc',
      f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzRE/2_workflow_quantiles/{WF}/{ssp}/{ssp}.NZInsarGPS1.NZInsarGPS1.verticallandmotion_localsl.nc']
#
fn.showFIG(axes[0,0],file[0],stnIDX,region,ssp,options)
fn.showFIG(axes[0,1],file[1],stnIDX,region,ssp,options)
fn.showFIG(axes[1,0],file[2],stnIDX,region,ssp,options)
axes[1, 1].axis('off');
