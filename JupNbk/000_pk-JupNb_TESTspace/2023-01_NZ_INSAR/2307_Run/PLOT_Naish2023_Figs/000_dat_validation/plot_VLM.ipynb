# %%
import fun_plot_ as fn
#
pathEXP=f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/003_Public/NZ_ReRun_2307'
#
Loc='regional'
#
station=5000
#
PK='FACTS_1.0_NZ_pk'
PK1='FACTS_1.0_NZ_pk_updatedVLM'
GG='FACTS_NZ_ggg'
#
CONf='medium_confidence'
#
ssp='ssp245'
#
file=f'verticallandmotion_{ssp}_medium_confidence_values.nc'
#
pathPK=f'{pathEXP}/{Loc}/{PK}/{CONf}/{ssp}/{file}'
pathPK1=f'{pathEXP}/{Loc}/{PK1}/{CONf}/{ssp}/{file}'
pathGG=f'{pathEXP}/{Loc}/{GG}/{CONf}/{ssp}/{file}'

# %% [markdown]
# <p style="font-size: 16pt; color: blue; font-family: 'Times New Roman';">
#     Plot::
#     <span style="border: 2px solid black; padding: 2px;">oldVLM vs GGG </span>
# </p>

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(10, 2.5)); plt.subplots_adjust(wspace=0.4, hspace=0.2)
#
fn.plot_line(pathPK,station,'red',axes[0])
fn.plot_line(pathGG,station,'blue',axes[1])

# %% [markdown]
# <p style="font-size: 16pt; color: blue; font-family: 'Times New Roman';">
#     Plot::
#     <span style="border: 2px solid black; padding: 2px;">newVLM vs GGG </span>
# </p>

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(10, 2.5)); plt.subplots_adjust(wspace=0.4, hspace=0.2)
#
fn.plot_line(pathPK1,3800,'orange',axes[0])
fn.plot_line(pathGG,3800,'blue',axes[1])

# %%
close_indices =fn.StnLoc(pathGG,pathPK1)
# len(close_indices)
# close_indices[3800]

# %%
lat,lon=fn.LoadNC(pathGG)
lat1,lon1=fn.LoadNC(pathPK1)

# %%
lat_Idxed=lat1[close_indices]

# %%
num=0
print(f'\n{lat_Idxed[num]} \n{lat[num]}')
# Out:
# -34.7409
# -34.740926

# %%
import matplotlib.pyplot as plt
plt.plot(lat_Idxed,color='blue')
plt.plot(lat,color='red')
