# %% [markdown]
# <div style="border: 1px solid black; padding: 10px;">
#     <h1 style="color: blue;">
#         <span style="color: black;">
#             <b>PLOT::</b> Figures from <i>Naish et al. (2023)</i>
#             <a href="https://www.authorea.com/doi/full/10.1002/essoar.10511878.1"><u><i> https://</i></u></a>
#         </span>
#     </h1>
# </div>

# %% [markdown]
# <p style="font-size: 24px; color: blue">
#   <span style="font-size: 24pt;"> Figure 5::</span> &nbsp &nbsp
#   <span style="border: 2px solid black; padding: 1px;color: red;"> FACTS_1.0_NZ_pk </span>
# </p>

# %%
import Naish_et_al_Figure5_FUN1 as fn
#
pathEXP=f'/Users/dota/werk/2022_09_FACTS/002_facts-devel/2023_08_15_factsNZ/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/003_Public/NZ_ReRun_2307'
#
Loc='regional'
#
station=5000
#
PK='FACTS_1.0_NZ_pk'
PK1='FACTS_1.0_NZ_pk_updatedVLM'
GG='FACTS_NZ_ggg'
#
CONf='medium_confidence'
#
ssp='ssp245'
#
file=f'verticallandmotion_{ssp}_medium_confidence_values.nc'
#
pathPK=f'{pathEXP}/{Loc}/{PK}/{CONf}/{ssp}/{file}'
pathPK1=f'{pathEXP}/{Loc}/{PK1}/{CONf}/{ssp}/{file}'
pathGG=f'{pathEXP}/{Loc}/{GG}/{CONf}/{ssp}/{file}'

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(10, 2.5)); plt.subplots_adjust(wspace=0.4, hspace=0.2)
#
fn.plot_line(pathPK,station,'red',axes[0])
fn.plot_line(pathGG,station,'blue',axes[1])
