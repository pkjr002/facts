# %%
import numpy as np; 
import fun_nz_ppr_rate_fig_Naish_et_al_Figure4 as fn
#
ssp = ['ssp126', 'ssp245', 'ssp370', 'ssp585']
options = {
    'ylab': 'RMSL rise (m; rel 1995-2014)',
    'x_min': 2020, 'x_max': 2150,  'x_ticks': np.arange(2020, 2151, 10),
    'y_min': 0, 'y_max': .022,   'y_ticks': np.around(np.arange(0, .023, 0.002), decimals=1)}
#

# %% [markdown]
# <p style="font-size: 16pt; color: blue; font-family: 'Times New Roman';">
#         RATE FILE::
#         <span style="color:red; font-weight: bold; font-style: italic;"> NZ_ReRun / &nbsp </span>
#         <br>
#         <span style="font-size: 12pt; color: black;background-color: yellow;"> FACTS_NZ_ggg </span>
# </p>

# %%
station = 0; name = 'Regional'
folder = [f'../../003_Public/NZ_ReRun/FACTS_NZ_ggg/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)

# %% [markdown]
# <p style="font-size: 16pt; color: blue; font-family: 'Times New Roman';">
#         RATE FILE::
#         <span style="color:red; font-weight: bold; font-style: italic;"> NZ_ReRun / &nbsp </span>
#         <br>
#         <span style="font-size: 12pt; color: black;background-color: yellow;"> FACTS_1.0_NZ_pk </span>
# </p>

# %%
station = 0; name = 'Regional'
folder = [f'../../003_Public/NZ_ReRun/FACTS_1.0_NZ_pk/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)

# %% [markdown]
# <p style="font-size: 16pt; color: blue; font-family: 'Times New Roman';">
#         RATE FILE::
#         <span style="color:red; font-weight: bold; font-style: italic;"> NZ_ReRun_2307 / &nbsp </span>
#         <br>
#         <span style="font-size: 12pt; color: black;background-color: yellow;"> FACTS_NZ_ggg </span>
# </p>

# %%
station = 0; name = 'Regional'
folder = [f'../../003_Public/NZ_ReRun_2307/regional/FACTS_NZ_ggg/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)
