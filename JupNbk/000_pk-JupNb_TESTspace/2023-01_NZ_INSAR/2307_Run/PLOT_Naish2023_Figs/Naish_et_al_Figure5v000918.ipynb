# %% [markdown]
# <div style="border: 1px solid black; padding: 10px;">
#     <h1 style="color: blue;">
#         <span style="color: black;">
#             <b>PLOT::</b> Figures from <i>Naish et al. (2023)</i>
#             <a href="https://www.authorea.com/doi/full/10.1002/essoar.10511878.1"><u><i> https://</i></u></a>
#         </span>
#     </h1>
# </div>

# %%
import numpy as np; 
import Naish_et_al_Figure5_FUN_09_18 as fn
#
ssp = ['ssp126', 'ssp245', 'ssp370', 'ssp585']
# ssp = ['ssp126', 'ssp585']
options = {
    'ylab': 'Regional Sea Level Change (m)',
    'x_min': 2020, 'x_max': 2150,  'x_ticks': np.arange(2020, 2151, 10),
    'y_min': -0.6, 'y_max': 3.3,   'y_ticks': np.around(np.arange(-0.6, 3.31, 0.3), decimals=1)}
#

# %% [markdown]
# <p style="font-size: 24px; color: blue">
#   <span style="font-size: 24pt;"> Figure 5A:</span> for
#   <span style="border: 2px solid black; padding: 1px;color: red;"> FACTS_1.0_NZ_pk </span>
# </p>

# %%
station = 2502; name = 'Wellington TG'
folder = ['../003_Public/NZ_ReRun_2307/regional/FACTS_1.0_NZ_pk/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)

# %% [markdown]
# <p style="font-size: 24px; color: blue">
#   <span style="font-size: 24pt;"> Figure 5B:</span> for
#   <span style="border: 2px solid black; padding: 1px;color: red;"> FACTS_1.0_NZ_pk </span>
# </p>

# %%
station = 1233;  name = 'Auckland TG'
folder = ['../003_Public/NZ_ReRun_2307/regional/FACTS_1.0_NZ_pk/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)
