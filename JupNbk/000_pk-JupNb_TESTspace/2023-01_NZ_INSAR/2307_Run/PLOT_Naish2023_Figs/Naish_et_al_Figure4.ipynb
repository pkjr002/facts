# %% [markdown]
# <div style="border: 1px solid black; padding: 10px;">
#     <h1 style="color: blue;">
#         <span style="color: black;">
#             <b>PLOT::</b> Figures from <i>Naish et al. (2023)</i>
#             <a href="https://www.authorea.com/doi/full/10.1002/essoar.10511878.1"><u><i> https://</i></u></a>
#         </span>
#     </h1>
# </div>

# %% [markdown]
# <p style="font-size: 24px; color: orange">
#   <span style="font-size: 18pt;">Import data/plot functions and specify axis details :</span><br>
# </p>

# %%
import numpy as np; 
import fun_nz_ppr_fig_Naish_et_al_Figure4 as fn
#
ssp = ['ssp126', 'ssp245', 'ssp370', 'ssp585']
options = {
    'ylab': 'GMSL rise (m; rel 1995-2014)',
    'x_min': 2020, 'x_max': 2150,  'x_ticks': np.arange(2020, 2151, 10),
    'y_min': 0, 'y_max': 2.2,   'y_ticks': np.around(np.arange(0, 2.3, 0.2), decimals=1)}
#

# %% [markdown]
# <p style="font-size: 24px; color: red">
#   <span style="font-size: 24pt;"> <b><i>PLOT:: Figure 4: </b></i></span>
#   <span style="border: 2px solid black; padding: 1px;"> for nzOG VLM data </span>
# </p>

# %%
station = 0; name = 'Global'
folder = ['/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzOG_global/4_confidence_level_files/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)

# %% [markdown]
# <p style="font-size: 24px; color: red">
#   <span style="font-size: 24pt;"> <b><i>PLOT:: Figure 4: </b></i></span>
#   <span style="border: 2px solid black; padding: 4px;"> for ar6
#     <span style="font-size: 15px;background-color: green;">/projects/kopp/ar6 </span>
#   </span>
# </p>

# %%
station = 0; name = 'Global'
folder = [f'/projects/kopp/ar6/global/confidence_output_files/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)

# %% [markdown]
# --
# <p style="font-size: 24px; color: red">
#   <span style="font-size: 24pt;"><b><i>Compare:</i></b>
#     <span style="border: 2px solid black; padding: 1px;"> ar6 </span> &nbsp; &nbsp; vs &nbsp; &nbsp;
#     <span style="border: 2px solid black; padding: 1px;"> nzOG global </span>
#   </span>
# </p>

# %% [markdown]
# <p style="font-size: 24px; color: blue">
#   <span style="font-size: 24pt;"> <b><i>FOR::</b></i></span>
#   <span style="border: 2px solid black; padding: 1px;"> 2150 </span>
# </p>

# %%
station = 0; name = 'Global'
folder = ['/projects/kopp/ar6/global/confidence_output_files/medium_confidence',
          '/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzOG_global/4_confidence_level_files/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)

# %% [markdown]
# <p style="font-size: 24px; color: blue">
#   <span style="font-size: 24pt;"> <b><i>FOR::</b></i></span>
#   <span style="border: 2px solid black; padding: 1px;"> 2100 </span>
# </p>

# %%
import numpy as np; 
import fun_nz_ppr_fig_Naish_et_al_Figure4 as fn
#
ssp = ['ssp126', 'ssp245', 'ssp370', 'ssp585']
options = {
    'ylab': 'Sea Level Rise (m)',
    'x_min': 2020, 'x_max': 2100,  'x_ticks': np.arange(2020, 2101, 10),
    'y_min': 0, 'y_max': 2.2,   'y_ticks': np.around(np.arange(0, 2.21, 0.2), decimals=1),
    'yrST': 2020, 'yrEN': 2100} 
#

# %%
station = 0; name = 'Global'
folder = ['/projects/kopp/ar6/global/confidence_output_files/medium_confidence',
          '/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/002_Pbox_nzOG_global/4_confidence_level_files/medium_confidence']
fn.project_SL(folder,station, name, ssp, options)
