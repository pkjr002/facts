# %% [markdown]
# <p style="font-size: 24px; color: orange">
#   <span style="font-size: 18pt;">Import data/plot functions and specify axis details :</span><br>
# </p>

# %%
import numpy as np; 
import fun_larmip_ar6larmip_ggg_comparison as fn
#
# ssp = ['ssp126', 'ssp245', 'ssp370', 'ssp585']
ssp = ['ssp585']
options = {
    'ylab': 'Sea Level Rise (m)',
    'x_min': 2020, 'x_max': 2150,  'x_ticks': np.arange(2020, 2151, 10),
    'y_min': -0.6, 'y_max': 3.3,   'y_ticks': np.around(np.arange(-0.6, 3.31, 0.3), decimals=1)}
#

# %% [markdown]
# <div style="border: 1px solid black; padding: 10px;">
#     <h1 style="color: blue;">
#         <span style="color: black;">
#             <b>PLOT::</b> Figures from <i>Naish et al. (2023)</i>
#             <a href="https://www.authorea.com/doi/full/10.1002/essoar.10511878.1"><u><i> https://</i></u></a>
#         </span>
#     </h1>
# </div>

# %% [markdown]
# <p style="font-size: 24px; font-size: 24pt; color: red;">
#   <b><i>PLOT:: Figure 5 A : </b></i>
#   <span style="color: blue"> &nbsp&nbsp  larmip  &nbsp&nbsp  ar6larmip  &nbsp&nbsp  ggg  &nbsp&nbsp </span>
# </p>

# %%
station = 1863; name = 'Ohinepanea'
fn.project_SL(station, name, ssp, options)

# %%
import xarray as xr
#
ssp_value = 'ssp585'
#
# pk_update   = f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/Pbox_{ssp_value}ar6Larmip/4_confidence_level_files/medium_confidence/{ssp_value}/total_{ssp_value}_medium_confidence_values.nc'
pk_update   = f'/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/2307_Run/Pbox_{ssp_value}.OGlarmip/4_confidence_level_files/medium_confidence/{ssp_value}/total_{ssp_value}_medium_confidence_values.nc'

nc=xr.open_dataset(pk_update)
nc

# %%
pk_update = f'/projects/kopp/pk695/NZ_ReRun/FACTS_NZ_ggg/medium_confidence/ssp585/total_ssp585_medium_confidence_values.nc'
nc=xr.open_dataset(pk_update)
nc

# %% [markdown]
# ---
# <p style="font-size: 24px; color: red">
#   <span style="font-size: 24pt;">PLOT:: <b><i>Figure 5 B :</b></i></span><br>
# </p>

# %%
station = 2439;  name = 'Tora Oroi Stream'
fn.project_SL(station, name, ssp, options)

# %% [markdown]
# ---
# <p style="font-size: 24px; color: red">
#   <span style="font-size: 24pt;">PLOT:: <b><i>Figure 6 A:</b></i></span><br>
# </p>

# %%
options = {'ylab': 'Sea Level Rise (m)','x_min': 2020, 'x_max': 2150,  'x_ticks': np.arange(2020, 2151, 10),'y_min': -0.3, 'y_max': 2.7,   'y_ticks': np.around(np.arange(-0.3, 2.8, 0.3), decimals=1)}

# %%
station = 1233;  name = 'Auckland Tide Gauge'
fn.project_SL(station, name, ssp, options)

# %%
station = 1830;  name = 'Moturiki Tide Gauge'
fn.project_SL(station, name, ssp, options)

# %%
station = 2502;  name = 'Wellington Tide Gauge'
fn.project_SL(station, name, ssp, options)

# %%
station = 4333;  name = 'Lyttleton Tide Gauge'
fn.project_SL(station, name, ssp, options)

# %%
station = 4722;  name = 'Dunedin Tide Gauge'
fn.project_SL(station, name, ssp, options)
