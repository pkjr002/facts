# %% [markdown]
# <h1 style="color: blue;"><b><span style="color: black;">Compare:: projected SL between </span> <u>2k FACTS 1.0 </u>  .vs.  <u> FACTS (slurm)</u> </b> </h1>
# <!-- <p style="font-size: 24px; color: black;">
#   <span style="font-size: 24pt;">EXP Details:</span><br>
#   <span style="font-size: 16px; color: black;">FACTS 1.0 was run by varying sample size for the NZ study case.</span>
# </p> -->
#
# <p style="font-size: 16px; color: black;"> Compare the <b>LOCAL</b> output for 2100, 2150</p>

# %%
import QQ_fun_qq_2150 as fn
#
path2k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ/nzOG/nzOG.ssp585/output_local_ssp585/'
pathG='/projects/kopp/ggg46/nz_projections/regional/full_sample_components/'
#
loc=1233

# %% [markdown]
# ---

# %%
fn.plot(['larmip.larmip.AIS_localsl'],path2k,['icesheets-ipccar6-larmipicesheet-ssp585_AIS_localsl.nc'],pathG)
fn.plot(['ar5AIS.ipccar5.icesheets_WAIS_localsl.nc'],path2k,['icesheets-ar5-icesheets-ssp585_WAIS_localsl.nc'],pathG)
fn.plot(['ar5AIS.ipccar5.icesheets_EAIS_localsl.nc'],path2k,['icesheets-ar5-icesheets-ssp585_EAIS_localsl.nc'],pathG)
fn.plot(['GrIS1f.FittedISMIP.GrIS_GIS_localsl'],path2k,['icesheets-FittedISMIP-icesheets-ssp585_GIS_localsl.nc'],pathG)
#
wf=['wf1f','wf2f']
for ww0,ww1 in enumerate(wf):
    fn.plot([f'total.workflow.{ww1}.local.nc'],path2k,['total-workflow.nc'],f'/projects/kopp/ggg46/nz_projections/regional/full_sample_workflows/wf_{ww1[2:]}/ssp585/')

# %% [markdown]
# ---
# # All Others

# %%
fn.plot(['emuAIS.emulandice.AIS_localsl.nc'],path2k,['icesheets-ipccar6-ismipemuicesheet-ssp585_AIS_localsl.nc'],pathG)
fn.plot(['larmip.larmip.AIS_localsl'],path2k,['icesheets-ipccar6-larmipicesheet-ssp585_AIS_localsl.nc'],pathG)
fn.plot(['deconto21.deconto21.AIS_AIS_localsl.nc'],path2k,['icesheets-dp20-icesheet-ssp585_AIS_localsl.nc'],pathG)
fn.plot(['bamber19.bamber19.icesheets_AIS_localsl.nc'],path2k,['icesheets-ipccar6-bambericesheet-ssp585_AIS_localsl.nc'],pathG)
fn.plot(['ar5AIS.ipccar5.icesheets_WAIS_localsl.nc'],path2k,['icesheets-ar5-icesheets-ssp585_WAIS_localsl.nc'],pathG)
fn.plot(['ar5AIS.ipccar5.icesheets_EAIS_localsl.nc'],path2k,['icesheets-ar5-icesheets-ssp585_EAIS_localsl.nc'],pathG)

# %% [markdown]
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️

# %% [markdown]
# ---

# %%
fn.plot(['emuGrIS.emulandice.GrIS_localsl.nc'],path2k,['icesheets-ipccar6-ismipemuicesheet-ssp585_GIS_localsl.nc'],pathG)
fn.plot(['GrIS1f.FittedISMIP.GrIS_GIS_localsl'],path2k,['icesheets-FittedISMIP-icesheets-ssp585_GIS_localsl.nc'],pathG)
fn.plot(['bamber19.bamber19.icesheets_GIS_localsl.nc'],path2k,['icesheets-ipccar6-bambericesheet-ssp585_GIS_localsl.nc'],pathG)

# %% [markdown]
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️

# %% [markdown]
# ---

# %%
fn.plot(['emuglaciers.emulandice.glaciers_localsl.nc'],path2k,['glaciers-ipccar6-gmipemuglaciers-ssp585_localsl.nc'],pathG)
fn.plot(['ar5glaciers.ipccar5.glaciers_localsl.nc'],path2k,['glaciers-ar5-glaciersgmip2-ssp585_localsl.nc'],pathG)

# %% [markdown]
# 🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊

# %% [markdown]
# ---

# %%
wf=['wf1e','wf1f','wf2e','wf2f','wf3e','wf3f','wf4']
for ww0,ww1 in enumerate(wf):
    fn.plot([f'total.workflow.{ww1}.local.nc'],path2k,['total-workflow.nc'],f'/projects/kopp/ggg46/nz_projections/regional/full_sample_workflows/wf_{ww1[2:]}/ssp585/')

# %% [markdown]
# ☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️

# %% [markdown]
# ---

# %%
fn.plot(['sterodynamics_localsl.nc'],path2k,['oceandynamics-tlm-oceandynamics-ssp585_localsl.nc'],pathG)
fn.plot('verticallandmotion_localsl.nc',path2k,['verticallandmotion-NZ_InsarGPS-verticallandmotion_localsl.nc'],pathG)
fn.plot(['lws.ssp.landwaterstorage_localsl.nc'],path2k,['landwaterstorage-ssp-landwaterstorage-ssp585_localsl.nc'],pathG)
