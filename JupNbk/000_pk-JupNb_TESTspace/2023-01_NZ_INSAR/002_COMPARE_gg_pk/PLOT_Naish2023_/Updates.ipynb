# %% [markdown]
# <p style="font-size: 24pt; color: blue; font-family: 'Times New Roman';">
# Load the updated run::
# </p>

# %%
import xarray as xr
path="/home/pk695/FACTS_run/ssp585/output/"
file ='ssp585.larmip.larmip.AIS_localsl.nc'
nc=xr.open_dataset(path+file)
nc
# Out:
# <xarray.Dataset>
# Dimensions:           (samples: 2000, years: 29, locations: 7435)
# Coordinates:
#   * years             (years) int64 2020 2030 2040 2050 ... 2270 2280 2290 2300
#   * locations         (locations) int64 0 1 2 3 4 5 ... 7430 7431 7432 7433 7434
#   * samples           (samples) int64 0 1 2 3 4 5 ... 1995 1996 1997 1998 1999
# Data variables:
#     sea_level_change  (samples, years, locations) float32 ...
#     lat               (locations) float64 ...
#     lon               (locations) float64 ...
# Attributes:
#     description:  Local SLR contributions from icesheets according to LARMIP2...
#     history:      Created Wed Jul 26 13:08:22 2023
#     source:       FACTS: ssp585.larmip.larmip.AIS
#     scenario:     ssp585
#     baseyear:     2005

# %% [markdown]
# ---

# %%
location=nc['locations'].values
print('location = \n',location)
# Out:
# location =
#  [   0    1    2 ... 7432 7433 7434]

# %% [markdown]
# ---

# %%
years=nc['years'].values
print('years = \n',years)
# Out:
# years =
#  [2020 2030 2040 2050 2060 2070 2080 2090 2100 2110 2120 2130 2140 2150
#  2160 2170 2180 2190 2200 2210 2220 2230 2240 2250 2260 2270 2280 2290
#  2300]

# %% [markdown]
# ---
