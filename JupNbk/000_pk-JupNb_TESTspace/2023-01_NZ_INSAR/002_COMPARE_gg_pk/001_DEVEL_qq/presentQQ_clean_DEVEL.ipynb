# %% [markdown]
# <h1 style="color: blue;"><b><span style="color: black;">Compare:: Sampling Differences </span> <u>20k</u> .vs. <u>2k</u> sample </b> </h1>
# <p style="font-size: 24px; color: black;">
#   <span style="font-size: 24pt;">EXP Details:</span><br>
#   <span style="font-size: 16px; color: black;">FACTS 1.0 was run by varying sample size for the NZ study case.</span>
# </p>
#
# <ol style="font-size: 14px; color: black;">
#   <li> 20k sample exp was run with first 500 locations with the mem fix</li>
#   <li> 2k ample exp was run with loops of first first 500 locations over 8k locations.
#   <!-- <li> <b> Note </b> that the LOCATION is choocen by default and it is currently set to the first location <b>(0)</b> </li> -->
# </ol>
#
# <p style="font-size: 16px; color: black;"> First compare the <b>GLOBAL</b> output</p>

# %% [markdown]
# ---
# <p style="font-size: 24px; color: black;">
#   <span style="font-size: 24pt;">Plot Global 20k v 2k:</span><br>
# </p>

# %% [markdown]
# ---

# %%
import fun_qq_1Panel as fn
#
path20k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ.230608/nzOG/nzOG.ssp585.500loc/output/'
path2k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ/nzOG/nzOG.ssp585/output_global_ssp585/'
loc=0
#
# fn.plot(['emulandice.AIS_globalsl.nc'],path20k,['emulandice.AIS_globalsl.nc'],path2k,loc,2100)
# fn.plot(['larmip.larmip.AIS_globalsl'],path20k,['larmip.larmip.AIS_globalsl'],path2k,loc,2100)
# fn.plot(['emuGrIS.emulandice.GrIS_globalsl.nc'],path20k,['emuGrIS.emulandice.GrIS_globalsl.nc'],path2k,loc,2100)
# fn.plot(['GrIS1f.FittedISMIP.GrIS_GIS_globalsl'],path20k,['GrIS1f.FittedISMIP.GrIS_GIS_globalsl'],path2k,loc,2100)
# fn.plot(['sterodynamics_globalsl.nc'],path20k,['sterodynamics_globalsl.nc'],path2k,loc,2100)
# fn.plot(['total.workflow.wf2e.global.nc'],path20k,['total.workflow.wf2e.global.nc'],path2k,loc,2100)
# fn.plot(['total.workflow.wf3e.global.nc'],path20k,['total.workflow.wf3e.global.nc'],path2k,loc,2100)
# fn.plot(['total.workflow.wf4.global.nc'],path20k,['total.workflow.wf4.global.nc'],path2k,loc,2100)

# %% [markdown]
# ---

# %%
import fun_qq_1Panel_MOD as fn
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(11.25, 2.25))

fn.plot(['emulandice.AIS_globalsl.nc'], path20k, ['emulandice.AIS_globalsl.nc'], path2k, loc, 2100, axes[0])
fn.plot(['larmip.larmip.AIS_globalsl'], path20k, ['larmip.larmip.AIS_globalsl'], path2k, loc, 2100, axes[1])

plt.show()
