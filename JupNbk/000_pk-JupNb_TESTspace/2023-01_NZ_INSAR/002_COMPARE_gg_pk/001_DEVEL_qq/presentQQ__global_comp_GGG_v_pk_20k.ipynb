# %% [markdown]
# <h1 style="color: blue;"><b><span style="color: black;">Compare:: GGG (20k) .vs. PK (20k) sample </b> </h1>
# <p style="font-size: 16px; color: black;"> First compare the <b>GLOBAL</b> output</p>

# %% [markdown]
# ---
# <p style="font-size: 24px; color: black;">
#   <span style="font-size: 24pt;">Plot GGG v PK :</span><br>
# </p>

# %% [markdown]
# ---

# %%
import fun_qq_1Panel as fn
#
pathPK = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ.230608/nzOG/nzOG.ssp585.500loc/output/'
pathGG ='/projects/kopp/ggg46/nz_projections/global/full_sample_components/'
loc=0
#
fn.plot(['emuAIS.emulandice.AIS_globalsl.nc'],pathPK,['icesheets-ipccar6-ismipemuicesheet-ssp585_AIS_globalsl.nc'],pathGG,loc,2100)
fn.plot(['larmip.larmip.AIS_globalsl'],pathPK,['icesheets-ipccar6-larmipicesheet-ssp585_AIS_globalsl.nc'],pathGG,loc,2020, 2100)

fn.plot(['emuGrIS.emulandice.GrIS_globalsl.nc'],pathPK,['icesheets-ipccar6-ismipemuicesheet-ssp585_GIS_globalsl.nc'],pathGG,loc, 2100)
fn.plot(['GrIS1f.FittedISMIP.GrIS_GIS_globalsl'],pathPK,['icesheets-FittedISMIP-icesheets-ssp585_GIS_globalsl.nc'],pathGG,loc, 2100)

fn.plot(['emuglaciers.emulandice.glaciers_globalsl.nc'],pathPK,['glaciers-ipccar6-gmipemuglaciers-ssp585_globalsl.nc'],pathGG,loc, 2020,2100)

fn.plot(['sterodynamics_globalsl.nc'],pathPK,['oceandynamics-tlm-oceandynamics-ssp585_globalsl.nc'],pathGG,loc, 2020,2100)

# %% [markdown]
# ---

# %% [markdown]
# # TOTALS
# ---

# %%
wf=['wf1e','wf1f','wf2e','wf2f','wf3e','wf3f','wf4']
for ww0,ww1 in enumerate(wf):
    fn.plot([f'total.workflow.{ww1}.global.nc'],pathPK,['total-workflow.nc'],f'/projects/kopp/ggg46/nz_projections/global/full_sample_workflows/wf_{ww1[2:]}/ssp585/',loc, 2020,2100)
