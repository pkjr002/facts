# %%
import numpy as np
import pandas as pd
import xarray as xr
import glob

import os
import shutil
import re
import matplotlib.pyplot as plt
import statsmodels.api as sm
from matplotlib.colors import ListedColormap, BoundaryNorm
#
PD=os.getcwd(); PD
#
import fun_qq as fn

# %% [markdown]
# ---

# %%
path20k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ.230608/nzOG/nzOG.ssp585.500loc/output/'
path2k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ/nzOG/nzOG.ssp585/output_local_ssp585/'
loc=30
cc=['emulandice.AIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc,1)

# %% [markdown]
# ---

# %%
cc=['emulandice.AIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['larmip.larmip.AIS_localsl']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['deconto21.deconto21.AIS_AIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['bamber19.bamber19.icesheets_AIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['ar5AIS.ipccar5.icesheets_WAIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['ar5AIS.ipccar5.icesheets_EAIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/DEVEL_QQF001_local_rand.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpk695/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/DEVEL_QQF001_local_rand.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cc=['emulandice.AIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpk695/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/DEVEL_QQF001_local_rand.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # cc=['larmip.larmip.AIS_localsl']; fn.plot(cc,path20k,cc,path2k,loc)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpk695/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/DEVEL_QQF001_local_rand.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # cc=['deconto21.deconto21.AIS_AIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpk695/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/DEVEL_QQF001_local_rand.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # cc=['bamber19.bamber19.icesheets_AIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpk695/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/DEVEL_QQF001_local_rand.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> # cc=['ar5AIS.ipccar5.icesheets_WAIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpk695/scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/DEVEL_QQF001_local_rand.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # cc=['ar5AIS.ipccar5.icesheets_EAIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
#
# File /scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/fun_qq.py:48, in plot(search_terms1, path20k, search_terms2, path2k, loc, worldmap)
#      45     plot_wm(lat_lon20k[0],lat_lon20k[1])
#      46 else:
#      47     # Plot the QQ Plot
# ---> 48     plot_qqplot(time20k, slc20k, slc2k, data20k, data2k,lat_lon20k,lat_lon2k)
#
# File /scratch/pk695/FACTS/002_fork/facts/JupNbk/000_pk-JupNb_TESTspace/2023-01_NZ_INSAR/002_COMPARE_gg_pk/001_DEVEL_qq/fun_qq.py:103, in plot_qqplot(time20k, slc20k, slc2k, data20k, data2k, lat_lon20k, lat_lon2k)
#     100 xx2k = slc2k[:, yr0]
#     102 ax = axes[axno]
# --> 103 sm.qqplot_2samples(xx20k, xx2k, line='45', color='g',ax=ax)
#     104 ax.set_xlabel('20k-samples (mm)', fontsize=8)
#     105 ax.set_ylabel('2k-samples (mm)', fontsize=8)
#
# TypeError: qqplot_2samples() got an unexpected keyword argument 'color'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️

# %% [markdown]
# ---

# %%
# cc=['emuGrIS.emulandice.GrIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['GrIS1f.FittedISMIP.GrIS_GIS_localsl']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['bamber19.bamber19.icesheets_GIS_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️

# %% [markdown]
# ---

# %%
# cc=['emuglaciers.emulandice.glaciers_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['ar5glaciers.ipccar5.glaciers_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# 🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊

# %% [markdown]
# <hr style="border: 0; border-top: 1px solid; width: 100%;">

# %%
# cc=['sterodynamics_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['verticallandmotion_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['lws.ssp.landwaterstorage_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# ☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️

# %% [markdown]
# ---

# %%
# cc=['total.workflow.wf1e.local.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
# cc=['total.workflow.wf1f.local.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
# cc=['total.workflow.wf2e.local.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
# cc=['total.workflow.wf2f.local.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
# cc=['total.workflow.wf3e.local.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
# cc=['total.workflow.wf3f.local.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
# cc=['total.workflow.wf4.local.nc'] ;   fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# ☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️

# %% [markdown]
# ---
