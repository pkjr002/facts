# %%
import numpy as np
import pandas as pd
import xarray as xr
import glob
import os
import shutil
import re
import matplotlib.pyplot as plt
import statsmodels.api as sm
from matplotlib.colors import ListedColormap, BoundaryNorm
#
PD=os.getcwd(); PD
#
import fun_qq as fn

# %% [markdown]
# ---

# %%
path20k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ.230608/nzOG/nzOG.ssp585.500loc/output/'
path2k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ/nzOG/nzOG.ssp585/output_global_ssp585/'
loc=0

# %% [markdown]
# ---

# %%
cc=['emulandice.AIS_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['larmip.larmip.AIS_globalsl']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['deconto21.deconto21.AIS_AIS_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['bamber19.bamber19.icesheets_AIS_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['ar5AIS.ipccar5.icesheets_WAIS_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['ar5AIS.ipccar5.icesheets_EAIS_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️

# %% [markdown]
# ---

# %%
cc=['emuGrIS.emulandice.GrIS_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['GrIS1f.FittedISMIP.GrIS_GIS_globalsl']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['bamber19.bamber19.icesheets_GIS_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# ❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️❄️

# %% [markdown]
# ---

# %%
cc=['emuglaciers.emulandice.glaciers_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['ar5glaciers.ipccar5.glaciers_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# 🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊🧊

# %% [markdown]
# <hr style="border: 0; border-top: 1px solid; width: 100%;">

# %%
cc=['sterodynamics_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
# cc=['verticallandmotion_localsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)
cc=['lws.ssp.landwaterstorage_globalsl.nc']; fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# ☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️

# %% [markdown]
# ---

# %%
cc=['total.workflow.wf1e.global.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
cc=['total.workflow.wf1f.global.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
cc=['total.workflow.wf2e.global.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
cc=['total.workflow.wf2f.global.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
cc=['total.workflow.wf3e.global.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
cc=['total.workflow.wf3f.global.nc'];   fn.plot(cc,path20k,cc,path2k,loc)
cc=['total.workflow.wf4.global.nc'] ;   fn.plot(cc,path20k,cc,path2k,loc)

# %% [markdown]
# ☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️☕️

# %% [markdown]
# ---
