# %% [markdown]
# <h1 style="color: blue;"><b><span style="color: black;">Compare</span> <u>Greg</u> and <u>PK</u> data </b> </h1>
# <p style="font-size: 24px; color: black;"> Data Details </p>
# <ol style="font-size: 14px; color: black;">
#   <li>20k samples and 1 location</li>
#   <li> <b> Note </b> that the LOCATION is choocen by default and it is currently set to the first location <b>(0)</b> </li>
# </ol>
# <p> We will  now compare the <b>GLOBAL</b> files between the 2 runs</p>

# %%
import fun_qq as fn
#
path20k = '/scratch/pk695/FACTS/002_fork/facts/experimentsNZ.230608/nzOG/nzOG.ssp585.500loc/output/'
path2k=pathG='/projects/kopp/ggg46/nz_projections/regional/full_sample_components/'
loc=30
# fn.plot(['deconto21.deconto21.AIS_AIS_localsl.nc'],path20k,['icesheets-dp20-icesheet-ssp585_AIS_localsl.nc'],path2k,loc,1)

# %%
# fn.plot(['emuAIS.emulandice.AIS_localsl.nc'],path20k,['icesheets-ipccar6-ismipemuicesheet-ssp585_AIS_localsl.nc'],path2k,loc)
fn.plot(['deconto21.deconto21.AIS_AIS_localsl.nc'],path20k,['icesheets-dp20-icesheet-ssp585_AIS_localsl.nc'],path2k,loc)
# fn.plot(['bamber19.bamber19.icesheets_AIS_localsl.nc'],path20k,['icesheets-ipccar6-bambericesheet-ssp585_AIS_localsl.nc'],path2k,loc)
# fn.plot(['ar5AIS.ipccar5.icesheets_WAIS_localsl.nc'],path20k,['icesheets-ar5-icesheets-ssp585_WAIS_localsl.nc'],path2k,loc)
# fn.plot(['ar5AIS.ipccar5.icesheets_EAIS_localsl.nc'],path20k,['icesheets-ar5-icesheets-ssp585_EAIS_localsl.nc'],path2k,loc)
