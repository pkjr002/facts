# %%
import numpy as np
import pandas as pd
import xarray as xr
from mpl_toolkits.basemap import Basemap
import glob
import os
import shutil
import re
import cartopy
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
#
# %matplotlib inline
# %matplotlib notebook
#
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap, BoundaryNorm
#
# PD=os.getcwd(); PD

import fn_plot_full_samp_wf_GrIS as FN

# %% [markdown]
# ###
# ### ==>
# ### <font color=black> PLOT <b>GrIS</b>:: <font color=blue> SSP126 </font> </font>

# %%
ssp='ssp126';       
folder='full_sample_workflows'
samp=[170,1050,1999,17,50,83] # you can choose 6 nos. Have to be below 2k. 
component="GrIS"
loc=np.arange(0,7) #Location:: choose from 0 to 7434  

FN.plot_full_samp_wf(ssp,folder,samp,component,loc)

# %% [markdown]
# ###
# ### ==>
# ### <font color=black> PLOT <b>GrIS</b>:: <font color=blue> SSP585 </font> </font>

# %%
ssp='ssp585';       
folder='full_sample_workflows'
samp=[170,1050,1999,17,50,83] # you can choose 6 nos. Have to be below 2k. 
component="GrIS"
loc=np.arange(0,7434) #Location:: choose from 0 to 7434  

FN.plot_full_samp_wf(ssp,folder,samp,component,loc)

# %% [markdown]
# ###
# ### ==>
# ### <font color=black> PLOT <b>GrIS</b>:: <font color=blue> SSP245 </font> </font>

# %%
ssp='ssp245';       
folder='full_sample_workflows'
samp=[170,1050,1999,17,50,83] # you can choose 6 nos. Have to be below 2k. 
component="GrIS"
loc=np.arange(0,7434) #Location:: choose from 0 to 7434  

FN.plot_full_samp_wf(ssp,folder,samp,component,loc)

# %% [markdown]
# ###
# ### ==>
# ### <font color=black> PLOT <b>GrIS</b>:: <font color=blue> SSP119 </font> </font>

# %%
ssp='ssp119';       
folder='full_sample_workflows'
samp=[170,1050,1999,17,50,83] # you can choose 6 nos. Have to be below 2k. 
component="GrIS"
loc=np.arange(0,7434) #Location:: choose from 0 to 7434  

FN.plot_full_samp_wf(ssp,folder,samp,component,loc)

# %% [markdown]
# ###
# ### ==>
# ### <font color=black> PLOT <b>GrIS</b>:: <font color=blue> SSP370 </font> </font>

# %%
ssp='ssp370';       
folder='full_sample_workflows'
samp=[170,1050,1999,17,50,83] # you can choose 6 nos. Have to be below 2k. 
component="GrIS"
loc=np.arange(0,7434) #Location:: choose from 0 to 7434  

FN.plot_full_samp_wf(ssp,folder,samp,component,loc)
