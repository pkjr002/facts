# %%
import pandas as pd


df_WF_AR6 = pd.read_csv('workflowtable-E-2100.tsv', sep='\t')
df_WF_AR6
# Out:
#     2100         wf_1e.ssp119        wf_1e.ssp126        wf_1e.ssp245  \
# 0     TE    0.12 (0.08--0.18)   0.15 (0.10--0.21)   0.22 (0.16--0.29)
# 1   GRIS   0.05 (-0.00--0.10)   0.06 (0.01--0.10)   0.08 (0.04--0.13)
# 2    AIS    0.09 (0.03--0.15)   0.09 (0.03--0.14)   0.08 (0.03--0.14)
# 3   GLAC    0.08 (0.06--0.10)   0.09 (0.07--0.11)   0.13 (0.10--0.15)
# 4    LWS    0.03 (0.02--0.04)   0.03 (0.02--0.04)   0.03 (0.02--0.04)
# 5  TOTAL    0.37 (0.28--0.47)   0.42 (0.33--0.52)   0.55 (0.45--0.66)
#
#          wf_1e.ssp370        wf_1e.ssp585  wf_1e.tlim1.5win0.25  \
# 0   0.28 (0.21--0.37)   0.33 (0.24--0.43)     0.14 (0.09--0.19)
# 1   0.12 (0.07--0.17)   0.14 (0.09--0.19)     0.07 (0.03--0.12)
# 2   0.09 (0.03--0.14)   0.08 (0.03--0.14)     0.08 (0.03--0.14)
# 3   0.16 (0.14--0.19)   0.18 (0.15--0.21)     0.11 (0.09--0.13)
# 4   0.04 (0.02--0.05)   0.03 (0.02--0.04)     0.03 (0.02--0.04)
# 5   0.68 (0.57--0.81)   0.77 (0.65--0.90)     0.44 (0.34--0.53)
#
# ...
