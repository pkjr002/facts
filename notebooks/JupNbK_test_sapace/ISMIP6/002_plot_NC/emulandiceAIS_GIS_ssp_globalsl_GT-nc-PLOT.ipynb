# %% [markdown]
# ## <font color=blue> ::Load Modules:: </font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import netCDF4 as nc
from netCDF4 import Dataset
from pandas.plotting import table 
import xarray as xr
from datetime import date
import time
import os

# %% [markdown]
# ---
# ### Load Data  <span style="color:blue"> <strong>SSP245 </strong> </span> data (Gt)

# %%
ssp = 245      #choose from: 245,585
#
data_nc=xr.open_dataset(os.getcwd()+"/emulandiceAIS_GIS_ssp{arg1}_globalsl_GT.nc".format(arg1=ssp))
data_nc
# Out:
# <xarray.Dataset>
# Dimensions:                (years: 9, quantiles: 3)
# Coordinates:
#   * years                  (years) int32 2020 2030 2040 2050 ... 2080 2090 2100
#   * quantiles              (quantiles) int64 50 17 83
# Data variables:
#     AIS_sea_level_change   (quantiles, years) int64 ...
#     EAIS_sea_level_change  (quantiles, years) int64 ...
#     WAIS_sea_level_change  (quantiles, years) int64 ...
#     PEN_sea_level_change   (quantiles, years) int64 ...
#     GIS_sea_level_change   (quantiles, years) int64 ...
# Attributes:
#     description:  Global SLR contribution from Antarctica using the emulandic...
#     history:      Created Sun Jun 18 05:05:41 2023
#     source:       ssp245.emuAIS.emulandice.AIS.  , ssp245.emuGrIS.emulandice....
#     scenario:     ssp245
#     baseyear:     2005
#     units:        Gigatonne (Gt)

# %% [markdown]
# ### Plot Data

# %%
COMPONENT = ['GIS','AIS','WAIS','EAIS','PEN']
unit = 'gt'
#
import fn_PLOT_emulandiceAIS_GIS as plot_fig 
plot_fig.plotALL(ssp,data_nc,COMPONENT,unit)

# %% [markdown]
# ---
# ### PLOT <span style="color:blue"> <strong>SSP585 </strong> </span> data

# %%
ssp = 585      
data_nc=xr.open_dataset(os.getcwd()+"/emulandiceAIS_GIS_ssp{arg1}_globalsl_GT.nc".format(arg1=ssp))
#
plot_fig.plotALL(ssp,data_nc,COMPONENT,unit)
