# %% [markdown]
# <span style="font-size:24pt; color:blue; font-family: 'Times New Roman'">Notebook::
#     <span style="color:green;"> Alternate Emissions </span>
# </span>
# <br>
# <span style="font-size:12pt; color:black; font-family:Georgia, serif;font-style:italic">Praveen Kumar and Kelly McCusker</span>
# <br>

# %% [markdown]
# <span style="font-family:'Courier New', monospace; font-size:14pt; color:black"> <b>Background::</b>
# <span style="background-color: yellow;"> working on it ... </span>
# </span>
# <br>

# %%
import numpy as np
import pandas as pd
import xarray as xr
import os
import shutil
import matplotlib.pyplot as plt
#
PD=os.getcwd()
import fun_altem as fn

# %% [markdown]
# <span style="font-size: 22pt; font-family: 'Times New Roman'; color: blue; "> Read::
#     <span style="font-size: 14pt; font-family: 'Times New Roman'; color: black; "> FACTS global only output</span>
# </span>

# %%
path = "../../experiments.RFF.SPs/global.coupling.ssp245/output/"

# %%
files = fn.list_files_with_names(path,['fair'])
files
# Out:
# ['global.coupling.ssp245.temperature.fair.temperature_climate.nc',
#  'global.coupling.ssp245.temperature.fair.temperature_gsat.nc',
#  'global.coupling.ssp245.temperature.fair.temperature_oceantemp.nc',
#  'global.coupling.ssp245.temperature.fair.temperature_ohc.nc']

# %%
print(files[0])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.temperature.fair.temperature_climate.nc
# <xarray.Dataset>
# Dimensions:              (samples: 500, years: 751, locations: 1)
# Coordinates:
#   * years                (years) int64 1750 1751 1752 1753 ... 2498 2499 2500
#   * locations            (locations) int64 -1
#   * samples              (samples) int64 0 1 2 3 4 5 ... 494 495 496 497 498 499
# Data variables:
#     surface_temperature  (samples, years, locations) float32 ...
#     lat                  (locations) float64 ...
#     lon                  (locations) float64 ...
# Attributes:
#     Source:                   FACTS
#     Date Created:             2024-01-26 15:45:32.966732
#     Description:              Fair v=1.6.4 scenario simulations with AR6-cali...
#     Method:                   Temperature and ocean heat content were returne...
#     Scenario emissions file:  ./rcmip/rcmip-emissions-annual-means-v5-1-0.csv
#     FAIR Parameters file:     ./parameters/fair_ar6_climate_params_v4.0.nc
#     FaIR version:             1.6.4
#     Scenario:                 ssp245
#     Centered:                 1850-1900 mean
#     Smoothing window:         19 years
#     Note:                     Code provided by Kelly McCusker of Rhodium Grou...

# %%
print(files[1])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.temperature.fair.temperature_gsat.nc
# <xarray.Dataset>
# Dimensions:              (samples: 500, years: 751, locations: 1)
# Coordinates:
#   * years                (years) int64 1750 1751 1752 1753 ... 2498 2499 2500
#   * locations            (locations) int64 -1
#   * samples              (samples) int64 0 1 2 3 4 5 ... 494 495 496 497 498 499
# Data variables:
#     surface_temperature  (samples, years, locations) float32 ...
#     lat                  (locations) float64 ...
#     lon                  (locations) float64 ...
# Attributes:
#     Source:                   FACTS
#     Date Created:             2024-01-26 15:45:32.966732
#     Description:              Fair v=1.6.4 scenario simulations with AR6-cali...
#     Method:                   Temperature and ocean heat content were returne...
#     Scenario emissions file:  ./rcmip/rcmip-emissions-annual-means-v5-1-0.csv
#     FAIR Parameters file:     ./parameters/fair_ar6_climate_params_v4.0.nc
#     FaIR version:             1.6.4
#     Scenario:                 ssp245
#     Centered:                 1850-1900 mean
#     Smoothing window:         19 years
#     Note:                     Code provided by Kelly McCusker of Rhodium Grou...

# %%
print(files[2])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.temperature.fair.temperature_oceantemp.nc
# <xarray.Dataset>
# Dimensions:              (samples: 500, years: 751, locations: 1)
# Coordinates:
#   * years                (years) int64 1750 1751 1752 1753 ... 2498 2499 2500
#   * locations            (locations) int64 -1
#   * samples              (samples) int64 0 1 2 3 4 5 ... 494 495 496 497 498 499
# Data variables:
#     surface_temperature  (samples, years, locations) float32 ...
#     lat                  (locations) float64 ...
#     lon                  (locations) float64 ...
# Attributes:
#     Source:                   FACTS
#     Date Created:             2024-01-26 15:45:32.966732
#     Description:              Fair v=1.6.4 scenario simulations with AR6-cali...
#     Method:                   Temperature and ocean heat content were returne...
#     Scenario emissions file:  ./rcmip/rcmip-emissions-annual-means-v5-1-0.csv
#     FAIR Parameters file:     ./parameters/fair_ar6_climate_params_v4.0.nc
#     FaIR version:             1.6.4
#     Scenario:                 ssp245
#     Centered:                 1850-1900 mean
#     Smoothing window:         19 years
#     Note:                     Code provided by Kelly McCusker of Rhodium Grou...

# %%
print(files[3])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.temperature.fair.temperature_ohc.nc
# <xarray.Dataset>
# Dimensions:              (samples: 500, years: 751, locations: 1)
# Coordinates:
#   * years                (years) int64 1750 1751 1752 1753 ... 2498 2499 2500
#   * locations            (locations) int64 -1
#   * samples              (samples) int64 0 1 2 3 4 5 ... 494 495 496 497 498 499
# Data variables:
#     surface_temperature  (samples, years, locations) float32 ...
#     lat                  (locations) float64 ...
#     lon                  (locations) float64 ...
# Attributes:
#     Source:                   FACTS
#     Date Created:             2024-01-26 15:45:32.966732
#     Description:              Fair v=1.6.4 scenario simulations with AR6-cali...
#     Method:                   Temperature and ocean heat content were returne...
#     Scenario emissions file:  ./rcmip/rcmip-emissions-annual-means-v5-1-0.csv
#     FAIR Parameters file:     ./parameters/fair_ar6_climate_params_v4.0.nc
#     FaIR version:             1.6.4
#     Scenario:                 ssp245
#     Centered:                 1850-1900 mean
#     Smoothing window:         19 years
#     Note:                     Code provided by Kelly McCusker of Rhodium Grou...

# %% [markdown]
# <span style="font-size: 22pt; font-family: 'Times New Roman'; color: blue; "> PLOT::
#     <span style="font-size: 14pt; font-family: 'Times New Roman'; color: black; "> .</span>
# </span>
