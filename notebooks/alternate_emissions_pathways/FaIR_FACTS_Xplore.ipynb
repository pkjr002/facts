# %% [markdown]
# <span style="font-size:24pt; color:blue; font-family: 'Times New Roman'">Notebook::
#     <span style="color:green;"> Alternate Emissions </span>
# </span>
# <br>
# <span style="font-size:12pt; color:black; font-family:Georgia, serif;font-style:italic">Praveen Kumar, Kelly McCusker, Bob Kopp, Alex Reedy</span>
# <br>

# %% [markdown]
# <span style="font-family:'Courier New', monospace; font-size:14pt; color:black"> <b>Background::</b>
# Run a alt emis.
# </span>
#
# <br>
#
# <span style="font-family:'Courier New', monospace; font-size:14pt; color:black"> <b>FACTS spec::</b> <br>
# For this experiment FACTS is running via a docker container. The installation is listed at <a href="https://fact-sealevel.readthedocs.io/en/latest/quickstart.html#">install.guide</a>
# </span>
#
# <br>

# %%
import numpy as np
import pandas as pd
import xarray as xr
import os
import shutil
import matplotlib.pyplot as plt
#
PD=os.getcwd()
import fun_altem as fn

# %% [markdown]
# <span style="font-size: 22pt; font-family: 'Times New Roman'; color: blue; "> Read::
#     <span style="font-size: 14pt; font-family: 'Times New Roman'; color: black; "> FACTS global only output</span>
# </span>

# %%
path = "../../experiments.RFF.SPs/global.coupling.ssp245/output/"

# %%
files = fn.list_files_with_names(path,['fair'])
files
# Out:
# ['global.coupling.ssp245.temperature.fair.temperature_climate.nc',
#  'global.coupling.ssp245.temperature.fair.temperature_gsat.nc',
#  'global.coupling.ssp245.temperature.fair.temperature_oceantemp.nc',
#  'global.coupling.ssp245.temperature.fair.temperature_ohc.nc']

# %%
files = fn.list_files_with_names(path,[])
files
# Out:
# ['global.coupling.ssp245.GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc',
#  'global.coupling.ssp245.ar5AIS.ipccar5.icesheets_AIS_globalsl.nc',
#  'global.coupling.ssp245.ar5AIS.ipccar5.icesheets_EAIS_globalsl.nc',
#  'global.coupling.ssp245.ar5AIS.ipccar5.icesheets_WAIS_globalsl.nc',
#  'global.coupling.ssp245.ar5glaciers.ipccar5.glaciers_globalsl.nc',
#  'global.coupling.ssp245.bamber19.bamber19.icesheets_AIS_globalsl.nc',
#  'global.coupling.ssp245.bamber19.bamber19.icesheets_EAIS_globalsl.nc',
#  'global.coupling.ssp245.bamber19.bamber19.icesheets_GIS_globalsl.nc',
#  'global.coupling.ssp245.bamber19.bamber19.icesheets_WAIS_globalsl.nc',
#  'global.coupling.ssp245.deconto21.deconto21.AIS_AIS_globalsl.nc',
#  'global.coupling.ssp245.deconto21.deconto21.AIS_EAIS_globalsl.nc',
#  'global.coupling.ssp245.deconto21.deconto21.AIS_WAIS_globalsl.nc',
#  'global.coupling.ssp245.larmip.larmip.AIS_EAIS_globalsl.nc',
#  'global.coupling.ssp245.larmip.larmip.AIS_PEN_globalsl.nc',
# ...

# %%
print(files[0])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.GrIS1f.FittedISMIP.GrIS_GIS_globalsl.nc
# <xarray.Dataset>
# Dimensions:           (years: 14, samples: 500, locations: 1)
# Coordinates:
#   * years             (years) int32 2020 2030 2040 2050 ... 2120 2130 2140 2150
#   * samples           (samples) int64 0 1 2 3 4 5 6 ... 494 495 496 497 498 499
#   * locations         (locations) int64 -1
# Data variables:
#     lat               (locations) float32 ...
#     lon               (locations) float32 ...
#     sea_level_change  (samples, years, locations) float32 ...
# Attributes:
#     description:  Global SLR contribution from {} according to AR5 workflow
#     history:      Created Fri May 17 17:32:34 2024
#     source:       FACTS: global.coupling.ssp245.ar5AIS.ipccar5.icesheets - ss...

# %%
print(files[1])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.ar5AIS.ipccar5.icesheets_AIS_globalsl.nc
# <xarray.Dataset>
# Dimensions:           (years: 14, samples: 500, locations: 1)
# Coordinates:
#   * years             (years) int32 2020 2030 2040 2050 ... 2120 2130 2140 2150
#   * samples           (samples) int64 0 1 2 3 4 5 6 ... 494 495 496 497 498 499
#   * locations         (locations) int64 -1
# Data variables:
#     lat               (locations) float32 ...
#     lon               (locations) float32 ...
#     sea_level_change  (samples, years, locations) float32 ...
# Attributes:
#     description:  Global SLR contribution from {} according to AR5 workflow
#     history:      Created Fri May 17 17:32:34 2024
#     source:       FACTS: global.coupling.ssp245.ar5AIS.ipccar5.icesheets - ss...

# %%
print(files[2])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.ar5AIS.ipccar5.icesheets_EAIS_globalsl.nc
# <xarray.Dataset>
# Dimensions:           (years: 14, samples: 500, locations: 1)
# Coordinates:
#   * years             (years) int32 2020 2030 2040 2050 ... 2120 2130 2140 2150
#   * samples           (samples) int64 0 1 2 3 4 5 6 ... 494 495 496 497 498 499
#   * locations         (locations) int64 -1
# Data variables:
#     lat               (locations) float32 ...
#     lon               (locations) float32 ...
#     sea_level_change  (samples, years, locations) float32 ...
# Attributes:
#     description:  Global SLR contribution from {} according to AR5 workflow
#     history:      Created Fri May 17 17:32:34 2024
#     source:       FACTS: global.coupling.ssp245.ar5AIS.ipccar5.icesheets - ss...

# %%
print(files[3])
nc_data=xr.open_dataset(path+files[1] , engine="netcdf4")
nc_data
# Out:
# global.coupling.ssp245.ar5AIS.ipccar5.icesheets_WAIS_globalsl.nc
# <xarray.Dataset>
# Dimensions:           (years: 14, samples: 500, locations: 1)
# Coordinates:
#   * years             (years) int32 2020 2030 2040 2050 ... 2120 2130 2140 2150
#   * samples           (samples) int64 0 1 2 3 4 5 6 ... 494 495 496 497 498 499
#   * locations         (locations) int64 -1
# Data variables:
#     lat               (locations) float32 ...
#     lon               (locations) float32 ...
#     sea_level_change  (samples, years, locations) float32 ...
# Attributes:
#     description:  Global SLR contribution from {} according to AR5 workflow
#     history:      Created Fri May 17 17:32:34 2024
#     source:       FACTS: global.coupling.ssp245.ar5AIS.ipccar5.icesheets - ss...

# %% [markdown]
# <span style="font-size: 22pt; font-family: 'Times New Roman'; color: blue; "> PLOT::
#     <span style="font-size: 14pt; font-family: 'Times New Roman'; color: black; "> .</span>
# </span>
